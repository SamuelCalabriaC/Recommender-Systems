# %% [markdown]
# <a href="https://colab.research.google.com/github/SamuelCalabriaC/Recommender-Systems/blob/main/SR-GNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx
import numpy as np
import tensorflow.compat.v1 as tf
import math
import warnings
from __future__ import division
import numpy as np
import pickle
import argparse
import datetime

"""
parser = argparse.ArgumentParser()
parser.add_argument('--dataset', default='sample', help='dataset name: diginetica/yoochoose1_4/yoochoose1_64/sample')
parser.add_argument('--method', type=str, default='ggnn', help='ggnn/gat/gcn')
parser.add_argument('--validation', action='store_true', help='validation')
parser.add_argument('--epoch', type=int, default=30, help='number of epochs to train for')
parser.add_argument('--batchSize', type=int, default=100, help='input batch size')
parser.add_argument('--hiddenSize', type=int, default=100, help='hidden state size')
parser.add_argument('--l2', type=float, default=1e-5, help='l2 penalty')
parser.add_argument('--lr', type=float, default=0.001, help='learning rate')
parser.add_argument('--step', type=int, default=1, help='gnn propogation steps')
parser.add_argument('--nonhybrid', action='store_true', help='global preference')
parser.add_argument('--lr_dc', type=float, default=0.1, help='learning rate decay rate')
parser.add_argument('--lr_dc_step', type=int, default=3, help='the number of steps after which the learning rate decay')
opt = parser.parse_args()
"""
tf.disable_v2_behavior()
tf.reset_default_graph()
warnings.filterwarnings('ignore')


train_data = pickle.load(open('train.txt', 'rb'))
test_data = pickle.load(open('test.txt', 'rb'))
# all_train_seq = pickle.load(open('../datasets/' + opt.dataset + '/all_train_seq.txt', 'rb'))

"""if opt.dataset == 'diginetica':
    n_node = 43098
elif opt.dataset == 'yoochoose1_64' or opt.dataset == 'yoochoose1_4':
    n_node = 37484
else:
  Tmall =  40727
    n_node = 310"""

# g = build_graph(all_train_seq)
train_data = Data(train_data, sub_graph=True, method='ggnn', shuffle=True)
test_data = Data(test_data, sub_graph=True, method='ggnn', shuffle=False)
model = GGNN(hidden_size=100, out_size=100, batch_size=100, n_node= 48727,
                 lr=0.001, l2=1e-5,  step=1, decay=3 * len(train_data.inputs) / 100, lr_dc=0.1,
                 nonhybrid='store_true')
print('CREACION DEL MODELO')
best_result = [0, 0,0,0,0,0,0,0]
best_epoch = [0, 0,0,0,0,0,0,0]
for epoch in range(30):
    print('epoch: ', epoch, '===========================================')
    slices = train_data.generate_batch(model.batch_size)
    fetches = [model.opt, model.loss_train, model.global_step]
    print('start training: ', datetime.datetime.now())
    loss_ = []
    for i, j in zip(slices, np.arange(len(slices))):
        adj_in, adj_out, alias, item, mask, targets = train_data.get_slice(i)
        _, loss, _ = model.run(fetches, targets, item, adj_in, adj_out, alias,  mask)
        loss_.append(loss)
    loss = np.mean(loss_)
    slices = test_data.generate_batch(model.batch_size)
    print('start predicting: ', datetime.datetime.now())

    hit20, mrr20, hit10, mrr10, hit5, mrr5, test_loss_ = [],[],[],[],[],[],[]
    for i, j in zip(slices, np.arange(len(slices))):
        adj_in, adj_out, alias, item, mask, targets = test_data.get_slice(i)
        scores, test_loss = model.run([model.score_test, model.loss_test], targets, item, adj_in, adj_out, alias,  mask)
        test_loss_.append(test_loss)
        # Ordena las puntuaciones y devuelve los índices 
        index20 = np.argsort(scores, 1)[:, -20:]
        index10 = np.argsort(scores, 1)[:,-10:]
        index5 = np.argsort(scores, 1)[:,-5:]

        cont = 0
        for score, target in zip(index20, targets):
            #print('Score: '+str(score)+' Target: '+str(target))
            hit20.append(np.isin(target - 1, score))
            if len(np.where(score == target - 1)[0]) == 0:
                mrr20.append(0)
            else:
                mrr20.append(1 / (20-np.where(score == target - 1)[0][0]))

        for score, target in zip(index10, targets):
            hit10.append(np.isin(target - 1, score))
            if len(np.where(score == target - 1)[0]) == 0:
                mrr10.append(0)
            else:
                mrr10.append(1 / (10-np.where(score == target - 1)[0][0]))

        for score, target in zip(index5, targets):
            hit5.append(np.isin(target - 1, score))
            if len(np.where(score == target - 1)[0]) == 0:
                mrr5.append(0)
            else:
                mrr5.append(1 / (5-np.where(score == target - 1)[0][0]))
    
    hit20 = np.mean(hit20)*100
    mrr20 = np.mean(mrr20)*100

    hit10 = np.mean(hit10)*100
    mrr10 = np.mean(mrr10)*100

    hit5 = np.mean(hit5)*100
    mrr5 = np.mean(mrr5)*100

    print('Hit 5: '+str(hit5))
    print('MRR 5: '+str(mrr5))

    test_loss = np.mean(test_loss_)

    if hit20 >= best_result[0]:
        best_result[0] = hit20
        best_epoch[0] = epoch
    if mrr20 >= best_result[1]:
        best_result[1] = mrr20
        best_epoch[1]=epoch

    if hit10 >= best_result[2]:
        best_result[2] = hit10
        best_epoch[2] = epoch
    if mrr10 >= best_result[3]:
        best_result[3] = mrr10
        best_epoch[3]=epoch

    if hit5 >= best_result[4]:
        best_result[4] = hit5
        best_epoch[4] = epoch
    if mrr5 >= best_result[5]:
        best_result[5] = mrr5
        best_epoch[5]=epoch

    print('train_loss:\t%.4f\ttest_loss:\t%4f\tHit@20:\t%.4f\tMMR@20:\t%.4f\tEpoch:\t%d,\t%d'
    %
          (loss, test_loss, best_result[0], best_result[1], best_epoch[0], best_epoch[1]))
    print('Hit@10: '+str(best_result[2]) + '  MMR@10: '+str(best_result[3])+'  Hit@5: '+str(best_result[4]) + '  MMR@5: '+str(best_result[5]))

# %% [markdown]
# # New Section

# %%
def build_graph(train_data):
    graph = nx.DiGraph()
    for seq in train_data:
        for i in range(len(seq) - 1):
            if graph.get_edge_data(seq[i], seq[i + 1]) is None:
                weight = 1
            else:
                weight = graph.get_edge_data(seq[i], seq[i + 1])['weight'] + 1
            graph.add_edge(seq[i], seq[i + 1], weight=weight)
    for node in graph.nodes:
        sum = 0
        for j, i in graph.in_edges(node):
            sum += graph.get_edge_data(j, i)['weight']
        if sum != 0:
            for j, i in graph.in_edges(i):
                graph.add_edge(j, i, weight=graph.get_edge_data(j, i)['weight'] / sum)
    return graph


def data_masks(all_usr_pois, item_tail):
    us_lens = [len(upois) for upois in all_usr_pois]
    len_max = max(us_lens)
    us_pois = [upois + item_tail * (len_max - le) for upois, le in zip(all_usr_pois, us_lens)]
    us_msks = [[1] * le + [0] * (len_max - le) for le in us_lens]
    return us_pois, us_msks, len_max


def split_validation(train_set, valid_portion):
    train_set_x, train_set_y = train_set
    n_samples = len(train_set_x)
    sidx = np.arange(n_samples, dtype='int32')
    np.random.shuffle(sidx)
    n_train = int(np.round(n_samples * (1. - valid_portion)))
    valid_set_x = [train_set_x[s] for s in sidx[n_train:]]
    valid_set_y = [train_set_y[s] for s in sidx[n_train:]]
    train_set_x = [train_set_x[s] for s in sidx[:n_train]]
    train_set_y = [train_set_y[s] for s in sidx[:n_train]]

    return (train_set_x, train_set_y), (valid_set_x, valid_set_y)


class Data():
    def __init__(self, data, sub_graph=False, method='ggnn', sparse=False, shuffle=False):
        inputs = data[0]
        inputs, mask, len_max = data_masks(inputs, [0])
        self.inputs = np.asarray(inputs)
        self.mask = np.asarray(mask)
        self.len_max = len_max
        self.targets = np.asarray(data[1])
        self.length = len(inputs)
        self.shuffle = shuffle
        self.sub_graph = sub_graph
        self.sparse = sparse
        self.method = method

    def generate_batch(self, batch_size):
        if self.shuffle:
            shuffled_arg = np.arange(self.length)
            np.random.shuffle(shuffled_arg)
            self.inputs = self.inputs[shuffled_arg]
            self.mask = self.mask[shuffled_arg]
            self.targets = self.targets[shuffled_arg]
        n_batch = int(self.length / batch_size)
        if self.length % batch_size != 0:
            n_batch += 1
        slices = np.split(np.arange(n_batch * batch_size), n_batch)
        slices[-1] = np.arange(self.length-batch_size, self.length)
        return slices

    def get_slice(self, index):
        if 1:
            items, n_node, A_in, A_out, alias_inputs = [], [], [], [], []
            for u_input in self.inputs[index]:
                n_node.append(len(np.unique(u_input)))
            max_n_node = np.max(n_node)
            if self.method == 'ggnn':
                for u_input in self.inputs[index]:
                    node = np.unique(u_input)
                    items.append(node.tolist() + (max_n_node - len(node)) * [0])
                    u_A = np.zeros((max_n_node, max_n_node))
                    for i in np.arange(len(u_input) - 1):
                        if u_input[i + 1] == 0:
                            break
                        u = np.where(node == u_input[i])[0][0]
                        v = np.where(node == u_input[i + 1])[0][0]
                        u_A[u][v] = 1
                    u_sum_in = np.sum(u_A, 0)
                    u_sum_in[np.where(u_sum_in == 0)] = 1
                    u_A_in = np.divide(u_A, u_sum_in)
                    u_sum_out = np.sum(u_A, 1)
                    u_sum_out[np.where(u_sum_out == 0)] = 1
                    u_A_out = np.divide(u_A.transpose(), u_sum_out)

                    A_in.append(u_A_in)
                    A_out.append(u_A_out)
                    alias_inputs.append([np.where(node == i)[0][0] for i in u_input])
                return A_in, A_out, alias_inputs, items, self.mask[index], self.targets[index]
            elif self.method == 'gat':
                A_in = []
                A_out = []
                for u_input in self.inputs[index]:
                    node = np.unique(u_input)
                    items.append(node.tolist() + (max_n_node - len(node)) * [0])
                    u_A = np.eye(max_n_node)
                    for i in np.arange(len(u_input) - 1):
                        if u_input[i + 1] == 0:
                            break
                        u = np.where(node == u_input[i])[0][0]
                        v = np.where(node == u_input[i + 1])[0][0]
                        u_A[u][v] = 1
                    A_in.append(-1e9 * (1 - u_A))
                    A_out.append(-1e9 * (1 - u_A.transpose()))
                    alias_inputs.append([np.where(node == i)[0][0] for i in u_input])
                return A_in, A_out, alias_inputs, items, self.mask[index], self.targets[index]

        else:
            return self.inputs[index], self.mask[index], self.targets[index]

class Model(object):
    def __init__(self, hidden_size=100, out_size=100, batch_size=100, nonhybrid=True):
        self.hidden_size = hidden_size
        self.out_size = out_size
        self.batch_size = batch_size
        self.mask = tf.placeholder(dtype=tf.float32)
        self.alias = tf.placeholder(dtype=tf.int32)  # 给给每个输入重新
        self.item = tf.placeholder(dtype=tf.int32)   # 重新编号的序列构成的矩阵
        self.tar = tf.placeholder(dtype=tf.int32)
        self.nonhybrid = nonhybrid
        self.stdv = 1.0 / math.sqrt(self.hidden_size)

        self.nasr_w1 = tf.get_variable('nasr_w1', [self.out_size, self.out_size], dtype=tf.float32,
                                       initializer=tf.random_uniform_initializer(-self.stdv, self.stdv))
        self.nasr_w2 = tf.get_variable('nasr_w2', [self.out_size, self.out_size], dtype=tf.float32,
                                       initializer=tf.random_uniform_initializer(-self.stdv, self.stdv))
        self.nasr_v = tf.get_variable('nasrv', [1, self.out_size], dtype=tf.float32,
                                      initializer=tf.random_uniform_initializer(-self.stdv, self.stdv))
        self.nasr_b = tf.get_variable('nasr_b', [self.out_size], dtype=tf.float32, initializer=tf.zeros_initializer())

    def forward(self, re_embedding, train=True):
        rm = tf.reduce_sum(self.mask, 1)
        last_id = tf.gather_nd(self.alias, tf.stack([tf.range(self.batch_size), tf.to_int32(rm)-1], axis=1))
        last_h = tf.gather_nd(re_embedding, tf.stack([tf.range(self.batch_size), last_id], axis=1))
        seq_h = tf.stack([tf.nn.embedding_lookup(re_embedding[i], self.alias[i]) for i in range(self.batch_size)],
                         axis=0)                                                           #batch_size*T*d
        last = tf.matmul(last_h, self.nasr_w1)
        seq = tf.matmul(tf.reshape(seq_h, [-1, self.out_size]), self.nasr_w2)
        last = tf.reshape(last, [self.batch_size, 1, -1])
        m = tf.nn.sigmoid(last + tf.reshape(seq, [self.batch_size, -1, self.out_size]) + self.nasr_b)
        coef = tf.matmul(tf.reshape(m, [-1, self.out_size]), self.nasr_v, transpose_b=True) * tf.reshape(
            self.mask, [-1, 1])
        b = self.embedding[1:]
        if not self.nonhybrid:
            ma = tf.concat([tf.reduce_sum(tf.reshape(coef, [self.batch_size, -1, 1]) * seq_h, 1),
                            tf.reshape(last, [-1, self.out_size])], -1)
            self.B = tf.get_variable('B', [2 * self.out_size, self.out_size],
                                     initializer=tf.random_uniform_initializer(-self.stdv, self.stdv))
            y1 = tf.matmul(ma, self.B)
            logits = tf.matmul(y1, b, transpose_b=True)
        else:
            ma = tf.reduce_sum(tf.reshape(coef, [self.batch_size, -1, 1]) * seq_h, 1)
            logits = tf.matmul(ma, b, transpose_b=True)
        loss = tf.reduce_mean(
            tf.nn.sparse_softmax_cross_entropy_with_logits(labels=self.tar - 1, logits=logits))
        self.vars = tf.trainable_variables()
        if train:
            lossL2 = tf.add_n([tf.nn.l2_loss(v) for v in self.vars if v.name not
                               in ['bias', 'gamma', 'b', 'g', 'beta']]) * self.L2
            loss = loss + lossL2
        return loss, logits

    def run(self, fetches, tar, item, adj_in, adj_out, alias, mask):
        return self.sess.run(fetches, feed_dict={self.tar: tar, self.item: item, self.adj_in: adj_in,
                                                 self.adj_out: adj_out, self.alias: alias, self.mask: mask})


class GGNN(Model):
    def __init__(self,hidden_size=100, out_size=100, batch_size=300, n_node=None,
                 lr=None, l2=None, step=1, decay=None, lr_dc=0.1, nonhybrid=False):
        super(GGNN,self).__init__(hidden_size, out_size, batch_size, nonhybrid)
        self.embedding = tf.get_variable(shape=[n_node, hidden_size], name='embedding', dtype=tf.float32,
                                         initializer=tf.random_uniform_initializer(-self.stdv, self.stdv))
        self.adj_in = tf.placeholder(dtype=tf.float32, shape=[self.batch_size, None, None])
        self.adj_out = tf.placeholder(dtype=tf.float32, shape=[self.batch_size, None, None])
        self.n_node = n_node
        self.L2 = l2
        self.step = step
        self.nonhybrid = nonhybrid
        self.W_in = tf.get_variable('W_in', shape=[self.out_size, self.out_size], dtype=tf.float32,
                                    initializer=tf.random_uniform_initializer(-self.stdv, self.stdv))
        self.b_in = tf.get_variable('b_in', [self.out_size], dtype=tf.float32,
                                    initializer=tf.random_uniform_initializer(-self.stdv, self.stdv))
        self.W_out = tf.get_variable('W_out', [self.out_size, self.out_size], dtype=tf.float32,
                                     initializer=tf.random_uniform_initializer(-self.stdv, self.stdv))
        self.b_out = tf.get_variable('b_out', [self.out_size], dtype=tf.float32,
                                     initializer=tf.random_uniform_initializer(-self.stdv, self.stdv))
        with tf.variable_scope('ggnn_model', reuse=None):
            self.loss_train, _ = self.forward(self.ggnn())
        with tf.variable_scope('ggnn_model', reuse=True):
            self.loss_test, self.score_test = self.forward(self.ggnn(), train=False)
        self.global_step = tf.Variable(0)
        self.learning_rate = tf.train.exponential_decay(lr, global_step=self.global_step, decay_steps=decay,
                                                        decay_rate=lr_dc, staircase=True)
        self.opt = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss_train, global_step=self.global_step)
        gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.8)
        config = tf.ConfigProto(gpu_options=gpu_options)
        config.gpu_options.allow_growth = True
        self.sess = tf.Session(config=config)
        self.sess.run(tf.global_variables_initializer())

    def ggnn(self):
        fin_state = tf.nn.embedding_lookup(self.embedding, self.item)
        cell = tf.nn.rnn_cell.GRUCell(self.out_size)
        with tf.variable_scope('gru'):
            for i in range(self.step):
                fin_state = tf.reshape(fin_state, [self.batch_size, -1, self.out_size])
                fin_state_in = tf.reshape(tf.matmul(tf.reshape(fin_state, [-1, self.out_size]),
                                                    self.W_in) + self.b_in, [self.batch_size, -1, self.out_size])
                fin_state_out = tf.reshape(tf.matmul(tf.reshape(fin_state, [-1, self.out_size]),
                                                     self.W_out) + self.b_out, [self.batch_size, -1, self.out_size])
                av = tf.concat([tf.matmul(self.adj_in, fin_state_in),
                                tf.matmul(self.adj_out, fin_state_out)], axis=-1)
                state_output, fin_state = \
                    tf.nn.dynamic_rnn(cell, tf.expand_dims(tf.reshape(av, [-1, 2*self.out_size]), axis=1),
                                      initial_state=tf.reshape(fin_state, [-1, self.out_size]))
        return tf.reshape(fin_state, [self.batch_size, -1, self.out_size])

# %%
#!/usr/bin/env python36
# -*- coding: utf-8 -*-
"""
Created on July, 2018
@author: Tangrizzly
"""

import argparse
import time
import csv
import pickle
import operator
import datetime
import os

"""parser = argparse.ArgumentParser()
parser.add_argument('--dataset', default='sample', help='dataset name: diginetica/yoochoose/sample')
opt = parser.parse_args()
print(opt)

dataset = 'sample_train-item-views.csv'
if opt.dataset == 'diginetica':
    dataset = 'train-item-views.csv'
elif opt.dataset =='yoochoose':
    dataset = 'yoochoose-clicks.dat'"""

print("-- Starting @ %ss" % datetime.datetime.now())
with open('train-item-views.csv', "r") as f:
    reader = csv.DictReader(f, delimiter=';')
    sess_clicks = {}
    sess_date = {}
    ctr = 0
    curid = -1
    curdate = None
    for data in reader:
        print(data)
        sessid = data['sessionId']
        if curdate and not curid == sessid:
            date = ''
            date = time.mktime(time.strptime(curdate, '%Y-%m-%d'))
            sess_date[curid] = date
        curid = sessid
        item = data['itemId'], int(data['timeframe'])
        curdate = ''
        curdate = data['eventdate']

        if sessid in sess_clicks:
            sess_clicks[sessid] += [item]
        else:
            sess_clicks[sessid] = [item]
        ctr += 1
    date = ''
    date = time.mktime(time.strptime(curdate, '%Y-%m-%d'))
    for i in list(sess_clicks):
        sorted_clicks = sorted(sess_clicks[i], key=operator.itemgetter(1))
        sess_clicks[i] = [c[0] for c in sorted_clicks]
    sess_date[curid] = date
print("-- Reading data @ %ss" % datetime.datetime.now())

# Filter out length 1 sessions
for s in list(sess_clicks):
    if len(sess_clicks[s]) == 1:
        del sess_clicks[s]
        del sess_date[s]

# Count number of times each item appears
iid_counts = {}
for s in sess_clicks:
    seq = sess_clicks[s]
    for iid in seq:
        if iid in iid_counts:
            iid_counts[iid] += 1
        else:
            iid_counts[iid] = 1

sorted_counts = sorted(iid_counts.items(), key=operator.itemgetter(1))

length = len(sess_clicks)
for s in list(sess_clicks):
    curseq = sess_clicks[s]
    filseq = list(filter(lambda i: iid_counts[i] >= 5, curseq))
    if len(filseq) < 2:
        del sess_clicks[s]
        del sess_date[s]
    else:
        sess_clicks[s] = filseq

# Split out test set based on dates
dates = list(sess_date.items())
maxdate = dates[0][1]

for _, date in dates:
    if maxdate < date:
        maxdate = date

# 7 days for test
splitdate = 0
splitdate = maxdate - 86400 * 7

print('Splitting date', splitdate)      # Yoochoose: ('Split date', 1411930799.0)
tra_sess = filter(lambda x: x[1] < splitdate, dates)
tes_sess = filter(lambda x: x[1] > splitdate, dates)

# Sort sessions by date
tra_sess = sorted(tra_sess, key=operator.itemgetter(1))     # [(session_id, timestamp), (), ]
tes_sess = sorted(tes_sess, key=operator.itemgetter(1))     # [(session_id, timestamp), (), ]
print(len(tra_sess))    # 186670    # 7966257
print(len(tes_sess))    # 15979     # 15324
print(tra_sess[:3])
print(tes_sess[:3])
print("-- Splitting train set and test set @ %ss" % datetime.datetime.now())

# Choosing item count >=5 gives approximately the same number of items as reported in paper
item_dict = {}
# Convert training sessions to sequences and renumber items to start from 1
def obtian_tra():
    train_ids = []
    train_seqs = []
    train_dates = []
    item_ctr = 1
    for s, date in tra_sess:
        seq = sess_clicks[s]
        outseq = []
        for i in seq:
            if i in item_dict:
                outseq += [item_dict[i]]
            else:
                outseq += [item_ctr]
                item_dict[i] = item_ctr
                item_ctr += 1
        if len(outseq) < 2:  # Doesn't occur
            continue
        train_ids += [s]
        train_dates += [date]
        train_seqs += [outseq]
    print(item_ctr)     # 43098, 37484
    return train_ids, train_dates, train_seqs


# Convert test sessions to sequences, ignoring items that do not appear in training set
def obtian_tes():
    test_ids = []
    test_seqs = []
    test_dates = []
    for s, date in tes_sess:
        seq = sess_clicks[s]
        outseq = []
        for i in seq:
            if i in item_dict:
                outseq += [item_dict[i]]
        if len(outseq) < 2:
            continue
        test_ids += [s]
        test_dates += [date]
        test_seqs += [outseq]
    return test_ids, test_dates, test_seqs


tra_ids, tra_dates, tra_seqs = obtian_tra()
tes_ids, tes_dates, tes_seqs = obtian_tes()


def process_seqs(iseqs, idates):
    out_seqs = []
    out_dates = []
    labs = []
    ids = []
    for id, seq, date in zip(range(len(iseqs)), iseqs, idates):
        for i in range(1, len(seq)):
            tar = seq[-i]
            labs += [tar]
            out_seqs += [seq[:-i]]
            out_dates += [date]
            ids += [id]
    return out_seqs, out_dates, labs, ids


tr_seqs, tr_dates, tr_labs, tr_ids = process_seqs(tra_seqs, tra_dates)
te_seqs, te_dates, te_labs, te_ids = process_seqs(tes_seqs, tes_dates)
tra = (tr_seqs, tr_labs)
tes = (te_seqs, te_labs)
print(len(tr_seqs))
print(len(te_seqs))
print(tr_seqs[:3], tr_dates[:3], tr_labs[:3])
print(te_seqs[:3], te_dates[:3], te_labs[:3])
all = 0

for seq in tra_seqs:
    all += len(seq)
for seq in tes_seqs:
    all += len(seq)
print('avg length: ', all/(len(tra_seqs) + len(tes_seqs) * 1.0))

if not os.path.exists('sample'):
    os.makedirs('sample')
pickle.dump(tra, open('sample/train.txt', 'wb'))
pickle.dump(tes, open('sample/test.txt', 'wb'))
pickle.dump(tra_seqs, open('sample/all_train_seq.txt', 'wb'))

print('Done.')
# Out:
# Streaming output truncated to the last 5000 lines.
# OrderedDict([('sessionId', '594997'), ('userId', 'NA'), ('itemId', '376396'), ('timeframe', '55264'), ('eventdate', '2016-04-13')])
# OrderedDict([('sessionId', '594998'), ('userId', 'NA'), ('itemId', '106054'), ('timeframe', '81379'), ('eventdate', '2016-04-28')])
# OrderedDict([('sessionId', '594998'), ('userId', 'NA'), ('itemId', '106054'), ('timeframe', '36411'), ('eventdate', '2016-04-28')])
# OrderedDict([('sessionId', '595003'), ('userId', 'NA'), ('itemId', '59914'), ('timeframe', '64513'), ('eventdate', '2016-04-20')])
# OrderedDict([('sessionId', '595008'), ('userId', '246745'), ('itemId', '26362'), ('timeframe', '28560'), ('eventdate', '2016-02-09')])
# OrderedDict([('sessionId', '595010'), ('userId', 'NA'), ('itemId', '11165'), ('timeframe', '14361'), ('eventdate', '2016-03-21')])
# OrderedDict([('sessionId', '595012'), ('userId', 'NA'), ('itemId', '82596'), ('timeframe', '120105'), ('eventdate', '2016-05-17')])
# OrderedDict([('sessionId', '595012'), ('userId', 'NA'), ('itemId', '96276'), ('timeframe', '192902'), ('eventdate', '2016-05-17')])
# OrderedDict([('sessionId', '595012'), ('userId', 'NA'), ('itemId', '125614'), ('timeframe', '59400'), ('eventdate', '2016-05-17')])
# OrderedDict([('sessionId', '595013'), ('userId', 'NA'), ('itemId', '18315'), ('timeframe', '21257'), ('eventdate', '2016-03-20')])
# OrderedDict([('sessionId', '595021'), ('userId', 'NA'), ('itemId', '8578'), ('timeframe', '87296'), ('eventdate', '2016-03-31')])
# OrderedDict([('sessionId', '595021'), ('userId', 'NA'), ('itemId', '12623'), ('timeframe', '114283'), ('eventdate', '2016-03-31')])
# OrderedDict([('sessionId', '595024'), ('userId', 'NA'), ('itemId', '53294'), ('timeframe', '21041'), ('eventdate', '2016-05-20')])
# OrderedDict([('sessionId', '595024'), ('userId', 'NA'), ('itemId', '375438'), ('timeframe', '93277'), ('eventdate', '2016-05-20')])
# OrderedDict([('sessionId', '595027'), ('userId', 'NA'), ('itemId', '56107'), ('timeframe', '87146'), ('eventdate', '2016-05-22')])
# OrderedDict([('sessionId', '595031'), ('userId', 'NA'), ('itemId', '11815'), ('timeframe', '17394'), ('eventdate', '2016-04-11')])
# OrderedDict([('sessionId', '595031'), ('userId', 'NA'), ('itemId', '79243'), ('timeframe', '145782'), ('eventdate', '2016-04-11')])
# OrderedDict([('sessionId', '595031'), ('userId', 'NA'), ('itemId', '233971'), ('timeframe', '550980'), ('eventdate', '2016-04-11')])
# OrderedDict([('sessionId', '595034'), ('userId', '246756'), ('itemId', '32324'), ('timeframe', '15313'), ('eventdate', '2016-02-10')])
# OrderedDict([('sessionId', '595034'), ('userId', '246756'), ('itemId', '62533'), ('timeframe', '150841'), ('eventdate', '2016-02-10')])
# OrderedDict([('sessionId', '595034'), ('userId', '246756'), ('itemId', '32095'), ('timeframe', '34130'), ('eventdate', '2016-02-10')])
# OrderedDict([('sessionId', '595034'), ('userId', '246756'), ('itemId', '104862'), ('timeframe', '192246'), ('eventdate', '2016-02-10')])
# OrderedDict([('sessionId', '595043'), ('userId', 'NA'), ('itemId', '11019'), ('timeframe', '84663'), ('eventdate', '2016-05-20')])
# OrderedDict([('sessionId', '595046'), ('userId', 'NA'), ('itemId', '3451'), ('timeframe', '195462'), ('eventdate', '2016-04-27')])
# OrderedDict([('sessionId', '595048'), ('userId', 'NA'), ('itemId', '77667'), ('timeframe', '18306'), ('eventdate', '2016-05-25')])
# OrderedDict([('sessionId', '595048'), ('userId', 'NA'), ('itemId', '5133'), ('timeframe', '131111'), ('eventdate', '2016-05-25')])
# OrderedDict([('sessionId', '595050'), ('userId', 'NA'), ('itemId', '61411'), ('timeframe', '41295'), ('eventdate', '2016-05-02')])
# OrderedDict([('sessionId', '595050'), ('userId', 'NA'), ('itemId', '61411'), ('timeframe', '136183'), ('eventdate', '2016-05-02')])
# OrderedDict([('sessionId', '595050'), ('userId', 'NA'), ('itemId', '2769'), ('timeframe', '231986'), ('eventdate', '2016-05-02')])
# OrderedDict([('sessionId', '595050'), ('userId', 'NA'), ('itemId', '11776'), ('timeframe', '112384'), ('eventdate', '2016-05-02')])
# OrderedDict([('sessionId', '595050'), ('userId', 'NA'), ('itemId', '390347'), ('timeframe', '185834'), ('eventdate', '2016-05-02')])
# OrderedDict([('sessionId', '595052'), ('userId', 'NA'), ('itemId', '149451'), ('timeframe', '18491'), ('eventdate', '2016-04-10')])
# OrderedDict([('sessionId', '595060'), ('userId', '28884'), ('itemId', '83535'), ('timeframe', '506953'), ('eventdate', '2016-05-25')])
# OrderedDict([('sessionId', '595060'), ('userId', '28884'), ('itemId', '83535'), ('timeframe', '38547'), ('eventdate', '2016-05-25')])
# OrderedDict([('sessionId', '595062'), ('userId', 'NA'), ('itemId', '198'), ('timeframe', '39181'), ('eventdate', '2016-05-01')])
# OrderedDict([('sessionId', '595066'), ('userId', '246773'), ('itemId', '124333'), ('timeframe', '200076'), ('eventdate', '2016-03-10')])
# OrderedDict([('sessionId', '595066'), ('userId', '246773'), ('itemId', '124676'), ('timeframe', '39168'), ('eventdate', '2016-03-10')])
# OrderedDict([('sessionId', '595072'), ('userId', 'NA'), ('itemId', '1771'), ('timeframe', '7803'), ('eventdate', '2016-04-03')])
# OrderedDict([('sessionId', '595072'), ('userId', 'NA'), ('itemId', '1771'), ('timeframe', '137596'), ('eventdate', '2016-04-03')])
# OrderedDict([('sessionId', '595072'), ('userId', 'NA'), ('itemId', '1771'), ('timeframe', '25759'), ('eventdate', '2016-04-03')])
# OrderedDict([('sessionId', '595076'), ('userId', '246779'), ('itemId', '12577'), ('timeframe', '28375'), ('eventdate', '2016-03-13')])
# OrderedDict([('sessionId', '595076'), ('userId', '246779'), ('itemId', '126416'), ('timeframe', '174661'), ('eventdate', '2016-03-13')])
# OrderedDict([('sessionId', '595076'), ('userId', '246779'), ('itemId', '136323'), ('timeframe', '270700'), ('eventdate', '2016-03-13')])
# OrderedDict([('sessionId', '595077'), ('userId', 'NA'), ('itemId', '76125'), ('timeframe', '233094'), ('eventdate', '2016-05-16')])
# OrderedDict([('sessionId', '595077'), ('userId', 'NA'), ('itemId', '131356'), ('timeframe', '1171714'), ('eventdate', '2016-05-16')])
# OrderedDict([('sessionId', '595077'), ('userId', 'NA'), ('itemId', '375508'), ('timeframe', '374623'), ('eventdate', '2016-05-16')])
# OrderedDict([('sessionId', '595077'), ('userId', 'NA'), ('itemId', '206409'), ('timeframe', '880153'), ('eventdate', '2016-05-16')])
# OrderedDict([('sessionId', '595077'), ('userId', 'NA'), ('itemId', '209899'), ('timeframe', '127093'), ('eventdate', '2016-05-16')])
# OrderedDict([('sessionId', '595077'), ('userId', 'NA'), ('itemId', '209899'), ('timeframe', '21750'), ('eventdate', '2016-05-16')])
# OrderedDict([('sessionId', '595086'), ('userId', 'NA'), ('itemId', '2521'), ('timeframe', '74921'), ('eventdate', '2016-04-06')])
# OrderedDict([('sessionId', '595086'), ('userId', 'NA'), ('itemId', '2521'), ('timeframe', '23302'), ('eventdate', '2016-04-06')])
# OrderedDict([('sessionId', '595086'), ('userId', 'NA'), ('itemId', '2521'), ('timeframe', '85607'), ('eventdate', '2016-04-06')])
# OrderedDict([('sessionId', '595089'), ('userId', '246783'), ('itemId', '144916'), ('timeframe', '81580'), ('eventdate', '2016-02-11')])
# OrderedDict([('sessionId', '595089'), ('userId', '246783'), ('itemId', '178131'), ('timeframe', '1129545'), ('eventdate', '2016-02-11')])
# OrderedDict([('sessionId', '595091'), ('userId', '246784'), ('itemId', '12577'), ('timeframe', '45417'), ('eventdate', '2016-02-25')])
# OrderedDict([('sessionId', '595093'), ('userId', '246786'), ('itemId', '10218'), ('timeframe', '104447'), ('eventdate', '2016-02-07')])
# OrderedDict([('sessionId', '595093'), ('userId', '246786'), ('itemId', '5301'), ('timeframe', '13241'), ('eventdate', '2016-02-07')])
# OrderedDict([('sessionId', '595095'), ('userId', '246789'), ('itemId', '7866'), ('timeframe', '17163'), ('eventdate', '2016-03-11')])
# OrderedDict([('sessionId', '595095'), ('userId', '246789'), ('itemId', '7866'), ('timeframe', '111366'), ('eventdate', '2016-03-11')])
# OrderedDict([('sessionId', '595095'), ('userId', '246789'), ('itemId', '29225'), ('timeframe', '190945'), ('eventdate', '2016-03-11')])
# OrderedDict([('sessionId', '595098'), ('userId', 'NA'), ('itemId', '8145'), ('timeframe', '50638'), ('eventdate', '2016-03-29')])
# OrderedDict([('sessionId', '595098'), ('userId', 'NA'), ('itemId', '2625'), ('timeframe', '56614'), ('eventdate', '2016-03-29')])
# OrderedDict([('sessionId', '595098'), ('userId', 'NA'), ('itemId', '413938'), ('timeframe', '82993'), ('eventdate', '2016-03-29')])
# OrderedDict([('sessionId', '595099'), ('userId', 'NA'), ('itemId', '56668'), ('timeframe', '73592'), ('eventdate', '2016-04-28')])
# OrderedDict([('sessionId', '595101'), ('userId', 'NA'), ('itemId', '225610'), ('timeframe', '308692'), ('eventdate', '2016-05-15')])
# OrderedDict([('sessionId', '595101'), ('userId', 'NA'), ('itemId', '79280'), ('timeframe', '90693'), ('eventdate', '2016-05-15')])
# OrderedDict([('sessionId', '595102'), ('userId', 'NA'), ('itemId', '58171'), ('timeframe', '65020'), ('eventdate', '2016-04-24')])
# OrderedDict([('sessionId', '595104'), ('userId', 'NA'), ('itemId', '25730'), ('timeframe', '21418'), ('eventdate', '2016-05-13')])
# OrderedDict([('sessionId', '595108'), ('userId', 'NA'), ('itemId', '95025'), ('timeframe', '10006'), ('eventdate', '2016-05-12')])
# OrderedDict([('sessionId', '595111'), ('userId', '246796'), ('itemId', '32756'), ('timeframe', '24524'), ('eventdate', '2016-03-16')])
# OrderedDict([('sessionId', '595118'), ('userId', '246799'), ('itemId', '37179'), ('timeframe', '228038'), ('eventdate', '2016-03-12')])
# OrderedDict([('sessionId', '595118'), ('userId', '246799'), ('itemId', '30420'), ('timeframe', '94316'), ('eventdate', '2016-03-12')])
# OrderedDict([('sessionId', '595118'), ('userId', '246799'), ('itemId', '30420'), ('timeframe', '181915'), ('eventdate', '2016-03-12')])
# OrderedDict([('sessionId', '595118'), ('userId', '246799'), ('itemId', '44220'), ('timeframe', '168436'), ('eventdate', '2016-03-12')])
# OrderedDict([('sessionId', '595119'), ('userId', '41925'), ('itemId', '135784'), ('timeframe', '140070'), ('eventdate', '2016-05-04')])
# OrderedDict([('sessionId', '595121'), ('userId', 'NA'), ('itemId', '376866'), ('timeframe', '15699'), ('eventdate', '2016-04-09')])
# OrderedDict([('sessionId', '595122'), ('userId', 'NA'), ('itemId', '90274'), ('timeframe', '32782'), ('eventdate', '2016-04-04')])
# OrderedDict([('sessionId', '595125'), ('userId', '246801'), ('itemId', '24707'), ('timeframe', '84695'), ('eventdate', '2016-02-11')])
# OrderedDict([('sessionId', '595125'), ('userId', '246801'), ('itemId', '128453'), ('timeframe', '26894'), ('eventdate', '2016-02-11')])
# OrderedDict([('sessionId', '595131'), ('userId', 'NA'), ('itemId', '87574'), ('timeframe', '746834'), ('eventdate', '2016-05-23')])
# OrderedDict([('sessionId', '595131'), ('userId', 'NA'), ('itemId', '57835'), ('timeframe', '788338'), ('eventdate', '2016-05-23')])
# OrderedDict([('sessionId', '595131'), ('userId', 'NA'), ('itemId', '19479'), ('timeframe', '802896'), ('eventdate', '2016-05-23')])
# OrderedDict([('sessionId', '595131'), ('userId', 'NA'), ('itemId', '6848'), ('timeframe', '70068'), ('eventdate', '2016-05-23')])
# OrderedDict([('sessionId', '595131'), ('userId', 'NA'), ('itemId', '14895'), ('timeframe', '542510'), ('eventdate', '2016-05-23')])
# OrderedDict([('sessionId', '595131'), ('userId', 'NA'), ('itemId', '14896'), ('timeframe', '290433'), ('eventdate', '2016-05-23')])
# OrderedDict([('sessionId', '595131'), ('userId', 'NA'), ('itemId', '376396'), ('timeframe', '561748'), ('eventdate', '2016-05-23')])
# OrderedDict([('sessionId', '595132'), ('userId', 'NA'), ('itemId', '31034'), ('timeframe', '52970'), ('eventdate', '2016-05-28')])
# OrderedDict([('sessionId', '595132'), ('userId', 'NA'), ('itemId', '82310'), ('timeframe', '153498'), ('eventdate', '2016-05-28')])
# OrderedDict([('sessionId', '595132'), ('userId', 'NA'), ('itemId', '1459'), ('timeframe', '12895'), ('eventdate', '2016-05-28')])
# OrderedDict([('sessionId', '595132'), ('userId', 'NA'), ('itemId', '2586'), ('timeframe', '121832'), ('eventdate', '2016-05-28')])
# OrderedDict([('sessionId', '595132'), ('userId', 'NA'), ('itemId', '3292'), ('timeframe', '205423'), ('eventdate', '2016-05-28')])
# OrderedDict([('sessionId', '595132'), ('userId', 'NA'), ('itemId', '11000'), ('timeframe', '183726'), ('eventdate', '2016-05-28')])
# OrderedDict([('sessionId', '595132'), ('userId', 'NA'), ('itemId', '34609'), ('timeframe', '90108'), ('eventdate', '2016-05-28')])
# OrderedDict([('sessionId', '595132'), ('userId', 'NA'), ('itemId', '88765'), ('timeframe', '236901'), ('eventdate', '2016-05-28')])
# OrderedDict([('sessionId', '595135'), ('userId', '246808'), ('itemId', '210872'), ('timeframe', '15501'), ('eventdate', '2016-05-24')])
# OrderedDict([('sessionId', '595135'), ('userId', '246808'), ('itemId', '25576'), ('timeframe', '93189'), ('eventdate', '2016-05-24')])
# OrderedDict([('sessionId', '595135'), ('userId', '246808'), ('itemId', '175868'), ('timeframe', '122532'), ('eventdate', '2016-05-24')])
# OrderedDict([('sessionId', '595135'), ('userId', '246808'), ('itemId', '395224'), ('timeframe', '67119'), ('eventdate', '2016-05-24')])
# OrderedDict([('sessionId', '595138'), ('userId', '246810'), ('itemId', '131786'), ('timeframe', '60073'), ('eventdate', '2016-03-08')])
# OrderedDict([('sessionId', '595143'), ('userId', '246812'), ('itemId', '84936'), ('timeframe', '74007'), ('eventdate', '2016-02-29')])
# OrderedDict([('sessionId', '595144'), ('userId', 'NA'), ('itemId', '913'), ('timeframe', '64322'), ('eventdate', '2016-05-28')])
# OrderedDict([('sessionId', '595144'), ('userId', 'NA'), ('itemId', '375888'), ('timeframe', '232796'), ('eventdate', '2016-05-28')])
# OrderedDict([('sessionId', '595145'), ('userId', '246813'), ('itemId', '13519'), ('timeframe', '484303'), ('eventdate', '2016-02-10')])
# OrderedDict([('sessionId', '595151'), ('userId', 'NA'), ('itemId', '90441'), ('timeframe', '336985'), ('eventdate', '2016-04-29')])
# OrderedDict([('sessionId', '595151'), ('userId', 'NA'), ('itemId', '159124'), ('timeframe', '230505'), ('eventdate', '2016-04-29')])
# OrderedDict([('sessionId', '595152'), ('userId', 'NA'), ('itemId', '5045'), ('timeframe', '147798'), ('eventdate', '2016-03-24')])
# OrderedDict([('sessionId', '595152'), ('userId', 'NA'), ('itemId', '47296'), ('timeframe', '53324'), ('eventdate', '2016-03-24')])
# OrderedDict([('sessionId', '595153'), ('userId', '246817'), ('itemId', '53671'), ('timeframe', '41181'), ('eventdate', '2016-03-16')])
# OrderedDict([('sessionId', '595154'), ('userId', '246818'), ('itemId', '79130'), ('timeframe', '95167'), ('eventdate', '2016-03-05')])
# OrderedDict([('sessionId', '595158'), ('userId', 'NA'), ('itemId', '16279'), ('timeframe', '3806'), ('eventdate', '2016-05-26')])
# OrderedDict([('sessionId', '595162'), ('userId', '246821'), ('itemId', '104332'), ('timeframe', '186430'), ('eventdate', '2016-02-26')])
# OrderedDict([('sessionId', '595164'), ('userId', '246822'), ('itemId', '293554'), ('timeframe', '566745'), ('eventdate', '2016-02-21')])
# OrderedDict([('sessionId', '595164'), ('userId', '246822'), ('itemId', '190690'), ('timeframe', '359973'), ('eventdate', '2016-02-21')])
# OrderedDict([('sessionId', '595164'), ('userId', '246822'), ('itemId', '145361'), ('timeframe', '343438'), ('eventdate', '2016-02-21')])
# OrderedDict([('sessionId', '595164'), ('userId', '246822'), ('itemId', '137765'), ('timeframe', '459903'), ('eventdate', '2016-02-21')])
# OrderedDict([('sessionId', '595164'), ('userId', '246822'), ('itemId', '186898'), ('timeframe', '170726'), ('eventdate', '2016-02-21')])
# OrderedDict([('sessionId', '595164'), ('userId', '246822'), ('itemId', '191442'), ('timeframe', '29497'), ('eventdate', '2016-02-21')])
# OrderedDict([('sessionId', '595164'), ('userId', '246822'), ('itemId', '51537'), ('timeframe', '270063'), ('eventdate', '2016-02-21')])
# OrderedDict([('sessionId', '595164'), ('userId', '246822'), ('itemId', '329516'), ('timeframe', '476648'), ('eventdate', '2016-02-21')])
# OrderedDict([('sessionId', '595164'), ('userId', '246822'), ('itemId', '212635'), ('timeframe', '496060'), ('eventdate', '2016-02-21')])
# OrderedDict([('sessionId', '595170'), ('userId', '246824'), ('itemId', '6538'), ('timeframe', '49722'), ('eventdate', '2016-02-07')])
# OrderedDict([('sessionId', '595174'), ('userId', 'NA'), ('itemId', '62425'), ('timeframe', '1150740'), ('eventdate', '2016-05-23')])
# OrderedDict([('sessionId', '595174'), ('userId', 'NA'), ('itemId', '88887'), ('timeframe', '872556'), ('eventdate', '2016-05-23')])
# OrderedDict([('sessionId', '595174'), ('userId', 'NA'), ('itemId', '88887'), ('timeframe', '65280'), ('eventdate', '2016-05-23')])
# OrderedDict([('sessionId', '595177'), ('userId', 'NA'), ('itemId', '4825'), ('timeframe', '62827'), ('eventdate', '2016-05-16')])
# OrderedDict([('sessionId', '595177'), ('userId', 'NA'), ('itemId', '7132'), ('timeframe', '12359'), ('eventdate', '2016-05-16')])
# OrderedDict([('sessionId', '595177'), ('userId', 'NA'), ('itemId', '376414'), ('timeframe', '18412'), ('eventdate', '2016-05-16')])
# OrderedDict([('sessionId', '595183'), ('userId', 'NA'), ('itemId', '162161'), ('timeframe', '93446'), ('eventdate', '2016-05-02')])
# OrderedDict([('sessionId', '595184'), ('userId', 'NA'), ('itemId', '9707'), ('timeframe', '156814'), ('eventdate', '2016-03-25')])
# OrderedDict([('sessionId', '595184'), ('userId', 'NA'), ('itemId', '9707'), ('timeframe', '85811'), ('eventdate', '2016-03-25')])
# OrderedDict([('sessionId', '595184'), ('userId', 'NA'), ('itemId', '131219'), ('timeframe', '48325'), ('eventdate', '2016-03-25')])
# OrderedDict([('sessionId', '595187'), ('userId', 'NA'), ('itemId', '3113'), ('timeframe', '34814'), ('eventdate', '2016-05-09')])
# OrderedDict([('sessionId', '595188'), ('userId', '246834'), ('itemId', '63248'), ('timeframe', '144026'), ('eventdate', '2016-03-14')])
# OrderedDict([('sessionId', '595188'), ('userId', '246834'), ('itemId', '12187'), ('timeframe', '16169'), ('eventdate', '2016-03-14')])
# OrderedDict([('sessionId', '595188'), ('userId', '246834'), ('itemId', '12187'), ('timeframe', '138103'), ('eventdate', '2016-03-14')])
# OrderedDict([('sessionId', '595189'), ('userId', 'NA'), ('itemId', '33355'), ('timeframe', '48155'), ('eventdate', '2016-05-29')])
# OrderedDict([('sessionId', '595190'), ('userId', 'NA'), ('itemId', '125043'), ('timeframe', '124067'), ('eventdate', '2016-04-09')])
# OrderedDict([('sessionId', '595191'), ('userId', 'NA'), ('itemId', '80911'), ('timeframe', '95642'), ('eventdate', '2016-03-22')])
# OrderedDict([('sessionId', '595192'), ('userId', 'NA'), ('itemId', '51205'), ('timeframe', '25341'), ('eventdate', '2016-05-30')])
# OrderedDict([('sessionId', '595192'), ('userId', 'NA'), ('itemId', '32008'), ('timeframe', '22228'), ('eventdate', '2016-05-30')])
# OrderedDict([('sessionId', '595193'), ('userId', 'NA'), ('itemId', '169294'), ('timeframe', '137243'), ('eventdate', '2016-04-20')])
# OrderedDict([('sessionId', '595195'), ('userId', '246835'), ('itemId', '34428'), ('timeframe', '269439'), ('eventdate', '2016-02-08')])
# OrderedDict([('sessionId', '595195'), ('userId', '246835'), ('itemId', '13930'), ('timeframe', '76499'), ('eventdate', '2016-02-08')])
# OrderedDict([('sessionId', '595196'), ('userId', 'NA'), ('itemId', '36271'), ('timeframe', '245363'), ('eventdate', '2016-05-02')])
# OrderedDict([('sessionId', '595200'), ('userId', 'NA'), ('itemId', '65623'), ('timeframe', '31583'), ('eventdate', '2016-04-13')])
# OrderedDict([('sessionId', '595202'), ('userId', 'NA'), ('itemId', '138161'), ('timeframe', '68298'), ('eventdate', '2016-05-17')])
# OrderedDict([('sessionId', '595202'), ('userId', 'NA'), ('itemId', '138161'), ('timeframe', '6256'), ('eventdate', '2016-05-17')])
# OrderedDict([('sessionId', '595202'), ('userId', 'NA'), ('itemId', '138161'), ('timeframe', '163679'), ('eventdate', '2016-05-17')])
# OrderedDict([('sessionId', '595206'), ('userId', '20616'), ('itemId', '3892'), ('timeframe', '760013'), ('eventdate', '2016-02-20')])
# OrderedDict([('sessionId', '595206'), ('userId', '20616'), ('itemId', '449991'), ('timeframe', '787207'), ('eventdate', '2016-02-20')])
# OrderedDict([('sessionId', '595206'), ('userId', '20616'), ('itemId', '149159'), ('timeframe', '887736'), ('eventdate', '2016-02-20')])
# OrderedDict([('sessionId', '595207'), ('userId', 'NA'), ('itemId', '80045'), ('timeframe', '1077436'), ('eventdate', '2016-04-15')])
# OrderedDict([('sessionId', '595207'), ('userId', 'NA'), ('itemId', '7258'), ('timeframe', '167339'), ('eventdate', '2016-04-15')])
# OrderedDict([('sessionId', '595207'), ('userId', 'NA'), ('itemId', '390595'), ('timeframe', '875963'), ('eventdate', '2016-04-15')])
# OrderedDict([('sessionId', '595211'), ('userId', '246842'), ('itemId', '27070'), ('timeframe', '23776'), ('eventdate', '2016-02-18')])
# OrderedDict([('sessionId', '595213'), ('userId', 'NA'), ('itemId', '23661'), ('timeframe', '58657'), ('eventdate', '2016-04-12')])
# OrderedDict([('sessionId', '595213'), ('userId', 'NA'), ('itemId', '375870'), ('timeframe', '165172'), ('eventdate', '2016-04-12')])
# OrderedDict([('sessionId', '595213'), ('userId', 'NA'), ('itemId', '375870'), ('timeframe', '390088'), ('eventdate', '2016-04-12')])
# OrderedDict([('sessionId', '595215'), ('userId', 'NA'), ('itemId', '13366'), ('timeframe', '41535'), ('eventdate', '2016-04-30')])
# OrderedDict([('sessionId', '595215'), ('userId', 'NA'), ('itemId', '68576'), ('timeframe', '121361'), ('eventdate', '2016-04-30')])
# OrderedDict([('sessionId', '595216'), ('userId', 'NA'), ('itemId', '144940'), ('timeframe', '89281'), ('eventdate', '2016-05-30')])
# OrderedDict([('sessionId', '595216'), ('userId', 'NA'), ('itemId', '174164'), ('timeframe', '172164'), ('eventdate', '2016-05-30')])
# OrderedDict([('sessionId', '595216'), ('userId', 'NA'), ('itemId', '6399'), ('timeframe', '100219'), ('eventdate', '2016-05-30')])
# OrderedDict([('sessionId', '595216'), ('userId', 'NA'), ('itemId', '6399'), ('timeframe', '24477'), ('eventdate', '2016-05-30')])
# OrderedDict([('sessionId', '595217'), ('userId', '246844'), ('itemId', '30165'), ('timeframe', '7612'), ('eventdate', '2016-03-13')])
# OrderedDict([('sessionId', '595218'), ('userId', 'NA'), ('itemId', '190650'), ('timeframe', '54333'), ('eventdate', '2016-05-30')])
# OrderedDict([('sessionId', '595219'), ('userId', 'NA'), ('itemId', '71734'), ('timeframe', '100537'), ('eventdate', '2016-05-20')])
# OrderedDict([('sessionId', '595223'), ('userId', 'NA'), ('itemId', '57991'), ('timeframe', '78694'), ('eventdate', '2016-04-17')])
# OrderedDict([('sessionId', '595223'), ('userId', 'NA'), ('itemId', '13892'), ('timeframe', '277051'), ('eventdate', '2016-04-17')])
# OrderedDict([('sessionId', '595224'), ('userId', '246848'), ('itemId', '360'), ('timeframe', '74028'), ('eventdate', '2016-03-15')])
# OrderedDict([('sessionId', '595224'), ('userId', '246848'), ('itemId', '47161'), ('timeframe', '31236'), ('eventdate', '2016-03-15')])
# OrderedDict([('sessionId', '595224'), ('userId', '246848'), ('itemId', '14424'), ('timeframe', '63373'), ('eventdate', '2016-03-15')])
# OrderedDict([('sessionId', '595224'), ('userId', '246848'), ('itemId', '47522'), ('timeframe', '26714'), ('eventdate', '2016-03-15')])
# OrderedDict([('sessionId', '595226'), ('userId', 'NA'), ('itemId', '69575'), ('timeframe', '190325'), ('eventdate', '2016-05-06')])
# OrderedDict([('sessionId', '595226'), ('userId', 'NA'), ('itemId', '7743'), ('timeframe', '669253'), ('eventdate', '2016-05-06')])
# OrderedDict([('sessionId', '595226'), ('userId', 'NA'), ('itemId', '175628'), ('timeframe', '53276'), ('eventdate', '2016-05-06')])
# OrderedDict([('sessionId', '595228'), ('userId', '246850'), ('itemId', '2405'), ('timeframe', '20076'), ('eventdate', '2016-03-15')])
# OrderedDict([('sessionId', '595229'), ('userId', 'NA'), ('itemId', '54060'), ('timeframe', '22610'), ('eventdate', '2016-05-15')])
# OrderedDict([('sessionId', '595230'), ('userId', 'NA'), ('itemId', '36155'), ('timeframe', '9779'), ('eventdate', '2016-04-10')])
# OrderedDict([('sessionId', '595242'), ('userId', '246858'), ('itemId', '35540'), ('timeframe', '192984'), ('eventdate', '2016-03-16')])
# OrderedDict([('sessionId', '595242'), ('userId', '246858'), ('itemId', '68462'), ('timeframe', '299822'), ('eventdate', '2016-03-16')])
# OrderedDict([('sessionId', '595242'), ('userId', '246858'), ('itemId', '69065'), ('timeframe', '254369'), ('eventdate', '2016-03-16')])
# OrderedDict([('sessionId', '595243'), ('userId', 'NA'), ('itemId', '33640'), ('timeframe', '62865'), ('eventdate', '2016-03-26')])
# OrderedDict([('sessionId', '595243'), ('userId', 'NA'), ('itemId', '66280'), ('timeframe', '137481'), ('eventdate', '2016-03-26')])
# OrderedDict([('sessionId', '595244'), ('userId', 'NA'), ('itemId', '79911'), ('timeframe', '147534'), ('eventdate', '2016-05-06')])
# OrderedDict([('sessionId', '595251'), ('userId', '246865'), ('itemId', '5779'), ('timeframe', '14526'), ('eventdate', '2016-03-12')])
# OrderedDict([('sessionId', '595253'), ('userId', 'NA'), ('itemId', '375334'), ('timeframe', '128609'), ('eventdate', '2016-05-16')])
# OrderedDict([('sessionId', '595253'), ('userId', 'NA'), ('itemId', '379043'), ('timeframe', '590088'), ('eventdate', '2016-05-16')])
# OrderedDict([('sessionId', '595254'), ('userId', 'NA'), ('itemId', '375425'), ('timeframe', '169556'), ('eventdate', '2016-05-03')])
# OrderedDict([('sessionId', '595254'), ('userId', 'NA'), ('itemId', '375867'), ('timeframe', '63795'), ('eventdate', '2016-05-03')])
# OrderedDict([('sessionId', '595254'), ('userId', 'NA'), ('itemId', '376402'), ('timeframe', '83788'), ('eventdate', '2016-05-03')])
# OrderedDict([('sessionId', '595256'), ('userId', 'NA'), ('itemId', '21204'), ('timeframe', '155176'), ('eventdate', '2016-04-16')])
# OrderedDict([('sessionId', '595256'), ('userId', 'NA'), ('itemId', '83292'), ('timeframe', '234909'), ('eventdate', '2016-04-16')])
# OrderedDict([('sessionId', '595256'), ('userId', 'NA'), ('itemId', '32007'), ('timeframe', '125620'), ('eventdate', '2016-04-16')])
# OrderedDict([('sessionId', '595256'), ('userId', 'NA'), ('itemId', '204557'), ('timeframe', '85501'), ('eventdate', '2016-04-16')])
# OrderedDict([('sessionId', '595259'), ('userId', 'NA'), ('itemId', '36706'), ('timeframe', '21928'), ('eventdate', '2016-04-02')])
# OrderedDict([('sessionId', '595260'), ('userId', 'NA'), ('itemId', '30883'), ('timeframe', '92363'), ('eventdate', '2016-04-16')])
# OrderedDict([('sessionId', '595260'), ('userId', 'NA'), ('itemId', '30883'), ('timeframe', '69613'), ('eventdate', '2016-04-16')])
# OrderedDict([('sessionId', '595260'), ('userId', 'NA'), ('itemId', '30883'), ('timeframe', '783403'), ('eventdate', '2016-04-16')])
# OrderedDict([('sessionId', '595261'), ('userId', '246868'), ('itemId', '22046'), ('timeframe', '65966'), ('eventdate', '2016-02-08')])
# OrderedDict([('sessionId', '595261'), ('userId', '246868'), ('itemId', '34154'), ('timeframe', '62438'), ('eventdate', '2016-02-08')])
# OrderedDict([('sessionId', '595262'), ('userId', '246869'), ('itemId', '14743'), ('timeframe', '83879'), ('eventdate', '2016-03-03')])
# OrderedDict([('sessionId', '595266'), ('userId', '246872'), ('itemId', '36358'), ('timeframe', '179222'), ('eventdate', '2016-03-04')])
# OrderedDict([('sessionId', '595268'), ('userId', 'NA'), ('itemId', '68352'), ('timeframe', '37666'), ('eventdate', '2016-06-01')])
# OrderedDict([('sessionId', '595275'), ('userId', '246877'), ('itemId', '34923'), ('timeframe', '24065'), ('eventdate', '2016-02-06')])
# OrderedDict([('sessionId', '595280'), ('userId', 'NA'), ('itemId', '79336'), ('timeframe', '109337'), ('eventdate', '2016-04-11')])
# OrderedDict([('sessionId', '595280'), ('userId', 'NA'), ('itemId', '79336'), ('timeframe', '385837'), ('eventdate', '2016-04-11')])
# OrderedDict([('sessionId', '595280'), ('userId', 'NA'), ('itemId', '126227'), ('timeframe', '12139'), ('eventdate', '2016-04-11')])
# OrderedDict([('sessionId', '595280'), ('userId', 'NA'), ('itemId', '80075'), ('timeframe', '203771'), ('eventdate', '2016-04-11')])
# OrderedDict([('sessionId', '595287'), ('userId', 'NA'), ('itemId', '134934'), ('timeframe', '393400'), ('eventdate', '2016-04-10')])
# OrderedDict([('sessionId', '595298'), ('userId', 'NA'), ('itemId', '39471'), ('timeframe', '14376'), ('eventdate', '2016-04-07')])
# OrderedDict([('sessionId', '595298'), ('userId', 'NA'), ('itemId', '14600'), ('timeframe', '294265'), ('eventdate', '2016-04-07')])
# OrderedDict([('sessionId', '595304'), ('userId', 'NA'), ('itemId', '11103'), ('timeframe', '127195'), ('eventdate', '2016-04-20')])
# OrderedDict([('sessionId', '595304'), ('userId', 'NA'), ('itemId', '13037'), ('timeframe', '213033'), ('eventdate', '2016-04-20')])
# OrderedDict([('sessionId', '595305'), ('userId', 'NA'), ('itemId', '179521'), ('timeframe', '81867'), ('eventdate', '2016-03-22')])
# OrderedDict([('sessionId', '595308'), ('userId', 'NA'), ('itemId', '376515'), ('timeframe', '72935'), ('eventdate', '2016-05-22')])
# OrderedDict([('sessionId', '595310'), ('userId', 'NA'), ('itemId', '133577'), ('timeframe', '26419'), ('eventdate', '2016-05-31')])
# OrderedDict([('sessionId', '595316'), ('userId', '246891'), ('itemId', '12836'), ('timeframe', '139185'), ('eventdate', '2016-03-15')])
# OrderedDict([('sessionId', '595316'), ('userId', '246891'), ('itemId', '132596'), ('timeframe', '107069'), ('eventdate', '2016-03-15')])
# OrderedDict([('sessionId', '595316'), ('userId', '246891'), ('itemId', '132596'), ('timeframe', '310335'), ('eventdate', '2016-03-15')])
# OrderedDict([('sessionId', '595316'), ('userId', '246891'), ('itemId', '13754'), ('timeframe', '288730'), ('eventdate', '2016-03-15')])
# OrderedDict([('sessionId', '595316'), ('userId', '246891'), ('itemId', '13754'), ('timeframe', '101782'), ('eventdate', '2016-03-15')])
# OrderedDict([('sessionId', '595316'), ('userId', '246891'), ('itemId', '14424'), ('timeframe', '79341'), ('eventdate', '2016-03-15')])
# OrderedDict([('sessionId', '595316'), ('userId', '246891'), ('itemId', '14424'), ('timeframe', '271867'), ('eventdate', '2016-03-15')])
# OrderedDict([('sessionId', '595318'), ('userId', 'NA'), ('itemId', '180265'), ('timeframe', '41271'), ('eventdate', '2016-05-11')])
# OrderedDict([('sessionId', '595321'), ('userId', 'NA'), ('itemId', '9368'), ('timeframe', '61625'), ('eventdate', '2016-04-26')])
# OrderedDict([('sessionId', '595321'), ('userId', 'NA'), ('itemId', '32758'), ('timeframe', '39774'), ('eventdate', '2016-04-26')])
# OrderedDict([('sessionId', '595322'), ('userId', 'NA'), ('itemId', '330801'), ('timeframe', '556958'), ('eventdate', '2016-05-25')])
# OrderedDict([('sessionId', '595322'), ('userId', 'NA'), ('itemId', '330801'), ('timeframe', '724326'), ('eventdate', '2016-05-25')])
# OrderedDict([('sessionId', '595322'), ('userId', 'NA'), ('itemId', '379037'), ('timeframe', '164702'), ('eventdate', '2016-05-25')])
# OrderedDict([('sessionId', '595322'), ('userId', 'NA'), ('itemId', '375990'), ('timeframe', '121004'), ('eventdate', '2016-05-25')])
# OrderedDict([('sessionId', '595328'), ('userId', 'NA'), ('itemId', '14889'), ('timeframe', '39412'), ('eventdate', '2016-04-12')])
# OrderedDict([('sessionId', '595338'), ('userId', 'NA'), ('itemId', '10987'), ('timeframe', '332657'), ('eventdate', '2016-05-10')])
# OrderedDict([('sessionId', '595338'), ('userId', 'NA'), ('itemId', '10657'), ('timeframe', '90348'), ('eventdate', '2016-05-10')])
# OrderedDict([('sessionId', '595338'), ('userId', 'NA'), ('itemId', '33355'), ('timeframe', '41906'), ('eventdate', '2016-05-10')])
# OrderedDict([('sessionId', '595338'), ('userId', 'NA'), ('itemId', '33355'), ('timeframe', '472685'), ('eventdate', '2016-05-10')])
# OrderedDict([('sessionId', '595338'), ('userId', 'NA'), ('itemId', '33355'), ('timeframe', '320613'), ('eventdate', '2016-05-10')])
# OrderedDict([('sessionId', '595344'), ('userId', 'NA'), ('itemId', '36155'), ('timeframe', '15542'), ('eventdate', '2016-04-09')])
# OrderedDict([('sessionId', '595345'), ('userId', 'NA'), ('itemId', '34318'), ('timeframe', '69187'), ('eventdate', '2016-03-30')])
# OrderedDict([('sessionId', '595347'), ('userId', '246906'), ('itemId', '126204'), ('timeframe', '43964'), ('eventdate', '2016-03-14')])
# OrderedDict([('sessionId', '595351'), ('userId', 'NA'), ('itemId', '12397'), ('timeframe', '172301'), ('eventdate', '2016-04-26')])
# OrderedDict([('sessionId', '595351'), ('userId', 'NA'), ('itemId', '12397'), ('timeframe', '394326'), ('eventdate', '2016-04-26')])
# OrderedDict([('sessionId', '595356'), ('userId', '246910'), ('itemId', '30626'), ('timeframe', '9751'), ('eventdate', '2016-02-17')])
# OrderedDict([('sessionId', '595356'), ('userId', '246910'), ('itemId', '5689'), ('timeframe', '136609'), ('eventdate', '2016-02-17')])
# OrderedDict([('sessionId', '595357'), ('userId', 'NA'), ('itemId', '31709'), ('timeframe', '549215'), ('eventdate', '2016-03-18')])
# OrderedDict([('sessionId', '595357'), ('userId', 'NA'), ('itemId', '33513'), ('timeframe', '21319'), ('eventdate', '2016-03-18')])
# OrderedDict([('sessionId', '595361'), ('userId', 'NA'), ('itemId', '13987'), ('timeframe', '88271'), ('eventdate', '2016-05-05')])
# OrderedDict([('sessionId', '595363'), ('userId', 'NA'), ('itemId', '169107'), ('timeframe', '14297'), ('eventdate', '2016-04-13')])
# OrderedDict([('sessionId', '595364'), ('userId', '246912'), ('itemId', '12700'), ('timeframe', '140035'), ('eventdate', '2016-03-14')])
# OrderedDict([('sessionId', '595364'), ('userId', '246912'), ('itemId', '13360'), ('timeframe', '163028'), ('eventdate', '2016-03-14')])
# OrderedDict([('sessionId', '595367'), ('userId', '246914'), ('itemId', '109028'), ('timeframe', '110416'), ('eventdate', '2016-02-19')])
# OrderedDict([('sessionId', '595368'), ('userId', 'NA'), ('itemId', '8784'), ('timeframe', '100710'), ('eventdate', '2016-05-07')])
# OrderedDict([('sessionId', '595368'), ('userId', 'NA'), ('itemId', '135079'), ('timeframe', '86273'), ('eventdate', '2016-05-07')])
# OrderedDict([('sessionId', '595368'), ('userId', 'NA'), ('itemId', '11525'), ('timeframe', '26149'), ('eventdate', '2016-05-07')])
# OrderedDict([('sessionId', '595368'), ('userId', 'NA'), ('itemId', '11525'), ('timeframe', '104489'), ('eventdate', '2016-05-07')])
# OrderedDict([('sessionId', '595368'), ('userId', 'NA'), ('itemId', '11525'), ('timeframe', '89470'), ('eventdate', '2016-05-07')])
# OrderedDict([('sessionId', '595368'), ('userId', 'NA'), ('itemId', '4637'), ('timeframe', '200173'), ('eventdate', '2016-05-07')])
# OrderedDict([('sessionId', '595368'), ('userId', 'NA'), ('itemId', '4637'), ('timeframe', '233636'), ('eventdate', '2016-05-07')])
# OrderedDict([('sessionId', '595370'), ('userId', '246916'), ('itemId', '29545'), ('timeframe', '34322'), ('eventdate', '2016-03-02')])
# OrderedDict([('sessionId', '595372'), ('userId', 'NA'), ('itemId', '35378'), ('timeframe', '5795'), ('eventdate', '2016-04-12')])
# OrderedDict([('sessionId', '595373'), ('userId', 'NA'), ('itemId', '36809'), ('timeframe', '9355'), ('eventdate', '2016-04-29')])
# OrderedDict([('sessionId', '595374'), ('userId', 'NA'), ('itemId', '5154'), ('timeframe', '46095'), ('eventdate', '2016-05-18')])
# OrderedDict([('sessionId', '595374'), ('userId', 'NA'), ('itemId', '126036'), ('timeframe', '176811'), ('eventdate', '2016-05-18')])
# OrderedDict([('sessionId', '595374'), ('userId', 'NA'), ('itemId', '128860'), ('timeframe', '103771'), ('eventdate', '2016-05-18')])
# OrderedDict([('sessionId', '595382'), ('userId', '246923'), ('itemId', '126189'), ('timeframe', '17533'), ('eventdate', '2016-02-27')])
# OrderedDict([('sessionId', '595382'), ('userId', '246923'), ('itemId', '24977'), ('timeframe', '34174'), ('eventdate', '2016-02-27')])
# OrderedDict([('sessionId', '595383'), ('userId', 'NA'), ('itemId', '17772'), ('timeframe', '378749'), ('eventdate', '2016-05-06')])
# OrderedDict([('sessionId', '595383'), ('userId', 'NA'), ('itemId', '3631'), ('timeframe', '258990'), ('eventdate', '2016-05-06')])
# OrderedDict([('sessionId', '595383'), ('userId', 'NA'), ('itemId', '68668'), ('timeframe', '673636'), ('eventdate', '2016-05-06')])
# OrderedDict([('sessionId', '595383'), ('userId', 'NA'), ('itemId', '6062'), ('timeframe', '869830'), ('eventdate', '2016-05-06')])
# OrderedDict([('sessionId', '595383'), ('userId', 'NA'), ('itemId', '57991'), ('timeframe', '156711'), ('eventdate', '2016-05-06')])
# OrderedDict([('sessionId', '595383'), ('userId', 'NA'), ('itemId', '90173'), ('timeframe', '480894'), ('eventdate', '2016-05-06')])
# OrderedDict([('sessionId', '595383'), ('userId', 'NA'), ('itemId', '36201'), ('timeframe', '782672'), ('eventdate', '2016-05-06')])
# OrderedDict([('sessionId', '595383'), ('userId', 'NA'), ('itemId', '13805'), ('timeframe', '85397'), ('eventdate', '2016-05-06')])
# OrderedDict([('sessionId', '595383'), ('userId', 'NA'), ('itemId', '47189'), ('timeframe', '645598'), ('eventdate', '2016-05-06')])
# OrderedDict([('sessionId', '595383'), ('userId', 'NA'), ('itemId', '19831'), ('timeframe', '217374'), ('eventdate', '2016-05-06')])
# OrderedDict([('sessionId', '595383'), ('userId', 'NA'), ('itemId', '233971'), ('timeframe', '827859'), ('eventdate', '2016-05-06')])
# OrderedDict([('sessionId', '595383'), ('userId', 'NA'), ('itemId', '6723'), ('timeframe', '173457'), ('eventdate', '2016-05-06')])
# OrderedDict([('sessionId', '595383'), ('userId', 'NA'), ('itemId', '36611'), ('timeframe', '893274'), ('eventdate', '2016-05-06')])
# OrderedDict([('sessionId', '595383'), ('userId', 'NA'), ('itemId', '247822'), ('timeframe', '803991'), ('eventdate', '2016-05-06')])
# OrderedDict([('sessionId', '595383'), ('userId', 'NA'), ('itemId', '14650'), ('timeframe', '856021'), ('eventdate', '2016-05-06')])
# OrderedDict([('sessionId', '595383'), ('userId', 'NA'), ('itemId', '25834'), ('timeframe', '705126'), ('eventdate', '2016-05-06')])
# OrderedDict([('sessionId', '595383'), ('userId', 'NA'), ('itemId', '25834'), ('timeframe', '750305'), ('eventdate', '2016-05-06')])
# OrderedDict([('sessionId', '595383'), ('userId', 'NA'), ('itemId', '80254'), ('timeframe', '1026836'), ('eventdate', '2016-05-06')])
# OrderedDict([('sessionId', '595383'), ('userId', 'NA'), ('itemId', '129084'), ('timeframe', '319301'), ('eventdate', '2016-05-06')])
# OrderedDict([('sessionId', '595383'), ('userId', 'NA'), ('itemId', '386891'), ('timeframe', '994171'), ('eventdate', '2016-05-06')])
# OrderedDict([('sessionId', '595383'), ('userId', 'NA'), ('itemId', '386045'), ('timeframe', '448475'), ('eventdate', '2016-05-06')])
# OrderedDict([('sessionId', '595386'), ('userId', '246925'), ('itemId', '31375'), ('timeframe', '612818'), ('eventdate', '2016-03-02')])
# OrderedDict([('sessionId', '595387'), ('userId', '246926'), ('itemId', '75556'), ('timeframe', '117413'), ('eventdate', '2016-03-11')])
# OrderedDict([('sessionId', '595390'), ('userId', 'NA'), ('itemId', '3655'), ('timeframe', '24893'), ('eventdate', '2016-03-29')])
# OrderedDict([('sessionId', '595391'), ('userId', '219392'), ('itemId', '29572'), ('timeframe', '21988'), ('eventdate', '2016-03-21')])
# OrderedDict([('sessionId', '595392'), ('userId', 'NA'), ('itemId', '12030'), ('timeframe', '7684'), ('eventdate', '2016-04-28')])
# OrderedDict([('sessionId', '595392'), ('userId', 'NA'), ('itemId', '130513'), ('timeframe', '66440'), ('eventdate', '2016-04-28')])
# OrderedDict([('sessionId', '595392'), ('userId', 'NA'), ('itemId', '130513'), ('timeframe', '28639'), ('eventdate', '2016-04-28')])
# OrderedDict([('sessionId', '595392'), ('userId', 'NA'), ('itemId', '185587'), ('timeframe', '243795'), ('eventdate', '2016-04-28')])
# OrderedDict([('sessionId', '595392'), ('userId', 'NA'), ('itemId', '7005'), ('timeframe', '110204'), ('eventdate', '2016-04-28')])
# OrderedDict([('sessionId', '595392'), ('userId', 'NA'), ('itemId', '14518'), ('timeframe', '312605'), ('eventdate', '2016-04-28')])
# OrderedDict([('sessionId', '595392'), ('userId', 'NA'), ('itemId', '14613'), ('timeframe', '299604'), ('eventdate', '2016-04-28')])
# OrderedDict([('sessionId', '595392'), ('userId', 'NA'), ('itemId', '90621'), ('timeframe', '269760'), ('eventdate', '2016-04-28')])
# OrderedDict([('sessionId', '595392'), ('userId', 'NA'), ('itemId', '377671'), ('timeframe', '505513'), ('eventdate', '2016-04-28')])
# OrderedDict([('sessionId', '595392'), ('userId', 'NA'), ('itemId', '377671'), ('timeframe', '305608'), ('eventdate', '2016-04-28')])
# OrderedDict([('sessionId', '595393'), ('userId', '246928'), ('itemId', '5904'), ('timeframe', '5023'), ('eventdate', '2016-02-03')])
# OrderedDict([('sessionId', '595393'), ('userId', '246928'), ('itemId', '5904'), ('timeframe', '58043'), ('eventdate', '2016-02-03')])
# OrderedDict([('sessionId', '595394'), ('userId', 'NA'), ('itemId', '4622'), ('timeframe', '65346'), ('eventdate', '2016-04-19')])
# OrderedDict([('sessionId', '595399'), ('userId', 'NA'), ('itemId', '7005'), ('timeframe', '749224'), ('eventdate', '2016-05-04')])
# OrderedDict([('sessionId', '595399'), ('userId', 'NA'), ('itemId', '375427'), ('timeframe', '875246'), ('eventdate', '2016-05-04')])
# OrderedDict([('sessionId', '595399'), ('userId', 'NA'), ('itemId', '376984'), ('timeframe', '856260'), ('eventdate', '2016-05-04')])
# OrderedDict([('sessionId', '595399'), ('userId', 'NA'), ('itemId', '380084'), ('timeframe', '889471'), ('eventdate', '2016-05-04')])
# OrderedDict([('sessionId', '595399'), ('userId', 'NA'), ('itemId', '379153'), ('timeframe', '714326'), ('eventdate', '2016-05-04')])
# OrderedDict([('sessionId', '595402'), ('userId', '246932'), ('itemId', '22334'), ('timeframe', '28506'), ('eventdate', '2016-02-09')])
# OrderedDict([('sessionId', '595405'), ('userId', 'NA'), ('itemId', '79497'), ('timeframe', '95465'), ('eventdate', '2016-04-18')])
# OrderedDict([('sessionId', '595405'), ('userId', 'NA'), ('itemId', '391005'), ('timeframe', '349094'), ('eventdate', '2016-04-18')])
# OrderedDict([('sessionId', '595407'), ('userId', 'NA'), ('itemId', '19659'), ('timeframe', '21771'), ('eventdate', '2016-04-03')])
# OrderedDict([('sessionId', '595410'), ('userId', 'NA'), ('itemId', '11385'), ('timeframe', '378084'), ('eventdate', '2016-05-31')])
# OrderedDict([('sessionId', '595411'), ('userId', 'NA'), ('itemId', '171398'), ('timeframe', '60062'), ('eventdate', '2016-05-26')])
# OrderedDict([('sessionId', '595411'), ('userId', 'NA'), ('itemId', '379044'), ('timeframe', '165698'), ('eventdate', '2016-05-26')])
# OrderedDict([('sessionId', '595413'), ('userId', 'NA'), ('itemId', '7801'), ('timeframe', '29062'), ('eventdate', '2016-04-05')])
# OrderedDict([('sessionId', '595416'), ('userId', 'NA'), ('itemId', '621'), ('timeframe', '21865'), ('eventdate', '2016-05-25')])
# OrderedDict([('sessionId', '595416'), ('userId', 'NA'), ('itemId', '51349'), ('timeframe', '36631'), ('eventdate', '2016-05-25')])
# OrderedDict([('sessionId', '595418'), ('userId', '246937'), ('itemId', '6135'), ('timeframe', '17145'), ('eventdate', '2016-03-15')])
# OrderedDict([('sessionId', '595419'), ('userId', 'NA'), ('itemId', '37654'), ('timeframe', '23756'), ('eventdate', '2016-05-26')])
# OrderedDict([('sessionId', '595419'), ('userId', 'NA'), ('itemId', '27103'), ('timeframe', '90797'), ('eventdate', '2016-05-26')])
# OrderedDict([('sessionId', '595419'), ('userId', 'NA'), ('itemId', '27103'), ('timeframe', '64921'), ('eventdate', '2016-05-26')])
# OrderedDict([('sessionId', '595420'), ('userId', '246938'), ('itemId', '16511'), ('timeframe', '989739'), ('eventdate', '2016-03-12')])
# OrderedDict([('sessionId', '595420'), ('userId', '246938'), ('itemId', '16511'), ('timeframe', '53561'), ('eventdate', '2016-03-12')])
# OrderedDict([('sessionId', '595423'), ('userId', 'NA'), ('itemId', '24014'), ('timeframe', '231359'), ('eventdate', '2016-04-12')])
# OrderedDict([('sessionId', '595423'), ('userId', 'NA'), ('itemId', '10399'), ('timeframe', '62990'), ('eventdate', '2016-04-12')])
# OrderedDict([('sessionId', '595423'), ('userId', 'NA'), ('itemId', '126099'), ('timeframe', '102319'), ('eventdate', '2016-04-12')])
# OrderedDict([('sessionId', '595429'), ('userId', 'NA'), ('itemId', '6665'), ('timeframe', '59923'), ('eventdate', '2016-05-11')])
# OrderedDict([('sessionId', '595432'), ('userId', 'NA'), ('itemId', '302093'), ('timeframe', '33320'), ('eventdate', '2016-04-13')])
# OrderedDict([('sessionId', '595432'), ('userId', 'NA'), ('itemId', '302093'), ('timeframe', '82844'), ('eventdate', '2016-04-13')])
# OrderedDict([('sessionId', '595432'), ('userId', 'NA'), ('itemId', '302093'), ('timeframe', '223145'), ('eventdate', '2016-04-13')])
# OrderedDict([('sessionId', '595432'), ('userId', 'NA'), ('itemId', '125369'), ('timeframe', '69374'), ('eventdate', '2016-04-13')])
# OrderedDict([('sessionId', '595432'), ('userId', 'NA'), ('itemId', '133053'), ('timeframe', '174337'), ('eventdate', '2016-04-13')])
# OrderedDict([('sessionId', '595434'), ('userId', 'NA'), ('itemId', '79212'), ('timeframe', '74206'), ('eventdate', '2016-05-31')])
# OrderedDict([('sessionId', '595434'), ('userId', 'NA'), ('itemId', '232991'), ('timeframe', '41546'), ('eventdate', '2016-05-31')])
# OrderedDict([('sessionId', '595436'), ('userId', 'NA'), ('itemId', '58216'), ('timeframe', '760168'), ('eventdate', '2016-04-07')])
# OrderedDict([('sessionId', '595436'), ('userId', 'NA'), ('itemId', '79786'), ('timeframe', '766273'), ('eventdate', '2016-04-07')])
# OrderedDict([('sessionId', '595436'), ('userId', 'NA'), ('itemId', '30674'), ('timeframe', '356643'), ('eventdate', '2016-04-07')])
# OrderedDict([('sessionId', '595436'), ('userId', 'NA'), ('itemId', '30674'), ('timeframe', '259203'), ('eventdate', '2016-04-07')])
# OrderedDict([('sessionId', '595436'), ('userId', 'NA'), ('itemId', '8129'), ('timeframe', '607647'), ('eventdate', '2016-04-07')])
# OrderedDict([('sessionId', '595436'), ('userId', 'NA'), ('itemId', '96259'), ('timeframe', '388170'), ('eventdate', '2016-04-07')])
# OrderedDict([('sessionId', '595436'), ('userId', 'NA'), ('itemId', '34398'), ('timeframe', '590101'), ('eventdate', '2016-04-07')])
# OrderedDict([('sessionId', '595438'), ('userId', 'NA'), ('itemId', '153969'), ('timeframe', '64993'), ('eventdate', '2016-04-24')])
# OrderedDict([('sessionId', '595441'), ('userId', '246948'), ('itemId', '126418'), ('timeframe', '572154'), ('eventdate', '2016-02-08')])
# OrderedDict([('sessionId', '595443'), ('userId', 'NA'), ('itemId', '38411'), ('timeframe', '16744'), ('eventdate', '2016-05-24')])
# OrderedDict([('sessionId', '595443'), ('userId', 'NA'), ('itemId', '38411'), ('timeframe', '72040'), ('eventdate', '2016-05-24')])
# OrderedDict([('sessionId', '595443'), ('userId', 'NA'), ('itemId', '80186'), ('timeframe', '51838'), ('eventdate', '2016-05-24')])
# OrderedDict([('sessionId', '595447'), ('userId', '246950'), ('itemId', '136272'), ('timeframe', '152761'), ('eventdate', '2016-02-15')])
# OrderedDict([('sessionId', '595447'), ('userId', '246950'), ('itemId', '79772'), ('timeframe', '192334'), ('eventdate', '2016-02-15')])
# OrderedDict([('sessionId', '595447'), ('userId', '246950'), ('itemId', '79772'), ('timeframe', '265733'), ('eventdate', '2016-02-15')])
# OrderedDict([('sessionId', '595447'), ('userId', '246950'), ('itemId', '79772'), ('timeframe', '40580'), ('eventdate', '2016-02-15')])
# OrderedDict([('sessionId', '595449'), ('userId', 'NA'), ('itemId', '21801'), ('timeframe', '20239'), ('eventdate', '2016-03-27')])
# OrderedDict([('sessionId', '595449'), ('userId', 'NA'), ('itemId', '23429'), ('timeframe', '156651'), ('eventdate', '2016-03-27')])
# OrderedDict([('sessionId', '595450'), ('userId', 'NA'), ('itemId', '29996'), ('timeframe', '219779'), ('eventdate', '2016-05-30')])
# OrderedDict([('sessionId', '595450'), ('userId', 'NA'), ('itemId', '223150'), ('timeframe', '671230'), ('eventdate', '2016-05-30')])
# OrderedDict([('sessionId', '595450'), ('userId', 'NA'), ('itemId', '33838'), ('timeframe', '40534'), ('eventdate', '2016-05-30')])
# OrderedDict([('sessionId', '595450'), ('userId', 'NA'), ('itemId', '393979'), ('timeframe', '130544'), ('eventdate', '2016-05-30')])
# OrderedDict([('sessionId', '595451'), ('userId', '20755'), ('itemId', '63770'), ('timeframe', '11837'), ('eventdate', '2016-04-29')])
# OrderedDict([('sessionId', '595451'), ('userId', '20755'), ('itemId', '321781'), ('timeframe', '350989'), ('eventdate', '2016-04-29')])
# OrderedDict([('sessionId', '595451'), ('userId', '20755'), ('itemId', '58739'), ('timeframe', '142381'), ('eventdate', '2016-04-29')])
# ...
# OrderedDict([('sessionId', '600556'), ('userId', '249286'), ('itemId', '5530'), ('timeframe', '147493'), ('eventdate', '2016-03-16')])
# OrderedDict([('sessionId', '600556'), ('userId', '249286'), ('itemId', '7821'), ('timeframe', '38806'), ('eventdate', '2016-03-16')])
# OrderedDict([('sessionId', '600557'), ('userId', 'NA'), ('itemId', '135777'), ('timeframe', '441118'), ('eventdate', '2016-03-27')])
# OrderedDict([('sessionId', '600557'), ('userId', 'NA'), ('itemId', '5615'), ('timeframe', '280101'), ('eventdate', '2016-03-27')])
# OrderedDict([('sessionId', '600561'), ('userId', 'NA'), ('itemId', '181605'), ('timeframe', '120437'), ('eventdate', '2016-05-09')])
# OrderedDict([('sessionId', '600561'), ('userId', 'NA'), ('itemId', '167947'), ('timeframe', '51364'), ('eventdate', '2016-05-09')])
# OrderedDict([('sessionId', '600566'), ('userId', '249291'), ('itemId', '6440'), ('timeframe', '34765'), ('eventdate', '2016-03-08')])
# OrderedDict([('sessionId', '600566'), ('userId', '249291'), ('itemId', '199109'), ('timeframe', '267604'), ('eventdate', '2016-03-08')])
# OrderedDict([('sessionId', '600569'), ('userId', 'NA'), ('itemId', '80098'), ('timeframe', '48792'), ('eventdate', '2016-04-27')])
# OrderedDict([('sessionId', '600571'), ('userId', 'NA'), ('itemId', '48684'), ('timeframe', '135656'), ('eventdate', '2016-04-28')])
# OrderedDict([('sessionId', '600574'), ('userId', 'NA'), ('itemId', '2329'), ('timeframe', '1192167'), ('eventdate', '2016-03-29')])
# OrderedDict([('sessionId', '600574'), ('userId', 'NA'), ('itemId', '46642'), ('timeframe', '51332'), ('eventdate', '2016-03-29')])
# OrderedDict([('sessionId', '600574'), ('userId', 'NA'), ('itemId', '5352'), ('timeframe', '1043744'), ('eventdate', '2016-03-29')])
# OrderedDict([('sessionId', '600574'), ('userId', 'NA'), ('itemId', '47143'), ('timeframe', '102345'), ('eventdate', '2016-03-29')])
# OrderedDict([('sessionId', '600574'), ('userId', 'NA'), ('itemId', '47143'), ('timeframe', '1179854'), ('eventdate', '2016-03-29')])
# OrderedDict([('sessionId', '600578'), ('userId', 'NA'), ('itemId', '36031'), ('timeframe', '19399'), ('eventdate', '2016-05-25')])
# OrderedDict([('sessionId', '600578'), ('userId', 'NA'), ('itemId', '376543'), ('timeframe', '359900'), ('eventdate', '2016-05-25')])
# OrderedDict([('sessionId', '600578'), ('userId', 'NA'), ('itemId', '383878'), ('timeframe', '147203'), ('eventdate', '2016-05-25')])
# OrderedDict([('sessionId', '600586'), ('userId', '249301'), ('itemId', '165872'), ('timeframe', '144113'), ('eventdate', '2016-02-10')])
# OrderedDict([('sessionId', '600586'), ('userId', '249301'), ('itemId', '136296'), ('timeframe', '982411'), ('eventdate', '2016-02-10')])
# OrderedDict([('sessionId', '600590'), ('userId', '249303'), ('itemId', '14082'), ('timeframe', '30432'), ('eventdate', '2016-02-27')])
# OrderedDict([('sessionId', '600591'), ('userId', 'NA'), ('itemId', '10771'), ('timeframe', '65130'), ('eventdate', '2016-04-15')])
# OrderedDict([('sessionId', '600593'), ('userId', 'NA'), ('itemId', '8886'), ('timeframe', '69196'), ('eventdate', '2016-05-16')])
# OrderedDict([('sessionId', '600597'), ('userId', 'NA'), ('itemId', '26199'), ('timeframe', '45894'), ('eventdate', '2016-05-12')])
# OrderedDict([('sessionId', '600598'), ('userId', 'NA'), ('itemId', '12328'), ('timeframe', '397624'), ('eventdate', '2016-03-20')])
# OrderedDict([('sessionId', '600598'), ('userId', 'NA'), ('itemId', '1907'), ('timeframe', '253876'), ('eventdate', '2016-03-20')])
# OrderedDict([('sessionId', '600598'), ('userId', 'NA'), ('itemId', '10441'), ('timeframe', '57071'), ('eventdate', '2016-03-20')])
# OrderedDict([('sessionId', '600607'), ('userId', '249310'), ('itemId', '7101'), ('timeframe', '51630'), ('eventdate', '2016-03-14')])
# OrderedDict([('sessionId', '600607'), ('userId', '249310'), ('itemId', '136477'), ('timeframe', '410452'), ('eventdate', '2016-03-14')])
# OrderedDict([('sessionId', '600608'), ('userId', 'NA'), ('itemId', '72214'), ('timeframe', '48937'), ('eventdate', '2016-05-28')])
# OrderedDict([('sessionId', '600608'), ('userId', 'NA'), ('itemId', '1813'), ('timeframe', '228706'), ('eventdate', '2016-05-28')])
# OrderedDict([('sessionId', '600608'), ('userId', 'NA'), ('itemId', '31789'), ('timeframe', '325743'), ('eventdate', '2016-05-28')])
# OrderedDict([('sessionId', '600609'), ('userId', '249311'), ('itemId', '95761'), ('timeframe', '7043'), ('eventdate', '2016-02-04')])
# OrderedDict([('sessionId', '600609'), ('userId', '249311'), ('itemId', '349131'), ('timeframe', '103552'), ('eventdate', '2016-02-04')])
# OrderedDict([('sessionId', '600613'), ('userId', '249314'), ('itemId', '129412'), ('timeframe', '93216'), ('eventdate', '2016-02-06')])
# OrderedDict([('sessionId', '600613'), ('userId', '249314'), ('itemId', '33181'), ('timeframe', '164416'), ('eventdate', '2016-02-06')])
# OrderedDict([('sessionId', '600613'), ('userId', '249314'), ('itemId', '204829'), ('timeframe', '124369'), ('eventdate', '2016-02-06')])
# OrderedDict([('sessionId', '600613'), ('userId', '249314'), ('itemId', '14013'), ('timeframe', '40170'), ('eventdate', '2016-02-06')])
# OrderedDict([('sessionId', '600613'), ('userId', '249314'), ('itemId', '14013'), ('timeframe', '137918'), ('eventdate', '2016-02-06')])
# OrderedDict([('sessionId', '600616'), ('userId', 'NA'), ('itemId', '31297'), ('timeframe', '656041'), ('eventdate', '2016-03-28')])
# OrderedDict([('sessionId', '600616'), ('userId', 'NA'), ('itemId', '33650'), ('timeframe', '557676'), ('eventdate', '2016-03-28')])
# OrderedDict([('sessionId', '600616'), ('userId', 'NA'), ('itemId', '14191'), ('timeframe', '464319'), ('eventdate', '2016-03-28')])
# OrderedDict([('sessionId', '600616'), ('userId', 'NA'), ('itemId', '29887'), ('timeframe', '367726'), ('eventdate', '2016-03-28')])
# OrderedDict([('sessionId', '600616'), ('userId', 'NA'), ('itemId', '29887'), ('timeframe', '344405'), ('eventdate', '2016-03-28')])
# OrderedDict([('sessionId', '600616'), ('userId', 'NA'), ('itemId', '14437'), ('timeframe', '412480'), ('eventdate', '2016-03-28')])
# OrderedDict([('sessionId', '600616'), ('userId', 'NA'), ('itemId', '211867'), ('timeframe', '734799'), ('eventdate', '2016-03-28')])
# OrderedDict([('sessionId', '600616'), ('userId', 'NA'), ('itemId', '211867'), ('timeframe', '768931'), ('eventdate', '2016-03-28')])
# OrderedDict([('sessionId', '600618'), ('userId', '249316'), ('itemId', '53120'), ('timeframe', '60082'), ('eventdate', '2016-03-15')])
# OrderedDict([('sessionId', '600619'), ('userId', 'NA'), ('itemId', '1907'), ('timeframe', '168988'), ('eventdate', '2016-04-24')])
# OrderedDict([('sessionId', '600619'), ('userId', 'NA'), ('itemId', '121682'), ('timeframe', '75558'), ('eventdate', '2016-04-24')])
# OrderedDict([('sessionId', '600621'), ('userId', 'NA'), ('itemId', '58736'), ('timeframe', '240776'), ('eventdate', '2016-04-15')])
# OrderedDict([('sessionId', '600621'), ('userId', 'NA'), ('itemId', '7747'), ('timeframe', '10556'), ('eventdate', '2016-04-15')])
# OrderedDict([('sessionId', '600621'), ('userId', 'NA'), ('itemId', '15518'), ('timeframe', '67162'), ('eventdate', '2016-04-15')])
# OrderedDict([('sessionId', '600621'), ('userId', 'NA'), ('itemId', '75688'), ('timeframe', '134104'), ('eventdate', '2016-04-15')])
# OrderedDict([('sessionId', '600626'), ('userId', '249321'), ('itemId', '59850'), ('timeframe', '102947'), ('eventdate', '2016-02-08')])
# OrderedDict([('sessionId', '600627'), ('userId', 'NA'), ('itemId', '46209'), ('timeframe', '20436'), ('eventdate', '2016-05-31')])
# OrderedDict([('sessionId', '600629'), ('userId', '249322'), ('itemId', '35046'), ('timeframe', '335226'), ('eventdate', '2016-02-17')])
# OrderedDict([('sessionId', '600631'), ('userId', 'NA'), ('itemId', '15009'), ('timeframe', '143437'), ('eventdate', '2016-04-26')])
# OrderedDict([('sessionId', '600631'), ('userId', 'NA'), ('itemId', '253162'), ('timeframe', '315757'), ('eventdate', '2016-04-26')])
# OrderedDict([('sessionId', '600631'), ('userId', 'NA'), ('itemId', '7931'), ('timeframe', '397358'), ('eventdate', '2016-04-26')])
# OrderedDict([('sessionId', '600631'), ('userId', 'NA'), ('itemId', '9215'), ('timeframe', '494207'), ('eventdate', '2016-04-26')])
# OrderedDict([('sessionId', '600631'), ('userId', 'NA'), ('itemId', '22617'), ('timeframe', '525168'), ('eventdate', '2016-04-26')])
# OrderedDict([('sessionId', '600631'), ('userId', 'NA'), ('itemId', '131569'), ('timeframe', '191938'), ('eventdate', '2016-04-26')])
# OrderedDict([('sessionId', '600632'), ('userId', 'NA'), ('itemId', '88081'), ('timeframe', '142214'), ('eventdate', '2016-04-01')])
# OrderedDict([('sessionId', '600635'), ('userId', 'NA'), ('itemId', '19701'), ('timeframe', '167337'), ('eventdate', '2016-05-25')])
# OrderedDict([('sessionId', '600635'), ('userId', 'NA'), ('itemId', '14441'), ('timeframe', '273055'), ('eventdate', '2016-05-25')])
# OrderedDict([('sessionId', '600635'), ('userId', 'NA'), ('itemId', '14896'), ('timeframe', '16674'), ('eventdate', '2016-05-25')])
# OrderedDict([('sessionId', '600635'), ('userId', 'NA'), ('itemId', '176018'), ('timeframe', '39166'), ('eventdate', '2016-05-25')])
# OrderedDict([('sessionId', '600638'), ('userId', 'NA'), ('itemId', '10332'), ('timeframe', '186643'), ('eventdate', '2016-04-30')])
# OrderedDict([('sessionId', '600639'), ('userId', 'NA'), ('itemId', '2507'), ('timeframe', '172839'), ('eventdate', '2016-04-10')])
# OrderedDict([('sessionId', '600639'), ('userId', 'NA'), ('itemId', '84856'), ('timeframe', '31401'), ('eventdate', '2016-04-10')])
# OrderedDict([('sessionId', '600639'), ('userId', 'NA'), ('itemId', '84856'), ('timeframe', '103802'), ('eventdate', '2016-04-10')])
# OrderedDict([('sessionId', '600640'), ('userId', 'NA'), ('itemId', '80133'), ('timeframe', '28420'), ('eventdate', '2016-05-23')])
# OrderedDict([('sessionId', '600645'), ('userId', '249327'), ('itemId', '111039'), ('timeframe', '22520'), ('eventdate', '2016-02-06')])
# OrderedDict([('sessionId', '600645'), ('userId', '249327'), ('itemId', '62380'), ('timeframe', '13367'), ('eventdate', '2016-02-06')])
# OrderedDict([('sessionId', '600647'), ('userId', 'NA'), ('itemId', '71981'), ('timeframe', '13471'), ('eventdate', '2016-04-08')])
# OrderedDict([('sessionId', '600651'), ('userId', 'NA'), ('itemId', '31256'), ('timeframe', '191321'), ('eventdate', '2016-05-21')])
# OrderedDict([('sessionId', '600651'), ('userId', 'NA'), ('itemId', '25816'), ('timeframe', '204961'), ('eventdate', '2016-05-21')])
# OrderedDict([('sessionId', '600651'), ('userId', 'NA'), ('itemId', '25816'), ('timeframe', '163653'), ('eventdate', '2016-05-21')])
# OrderedDict([('sessionId', '600651'), ('userId', 'NA'), ('itemId', '25816'), ('timeframe', '85929'), ('eventdate', '2016-05-21')])
# OrderedDict([('sessionId', '600651'), ('userId', 'NA'), ('itemId', '25816'), ('timeframe', '209460'), ('eventdate', '2016-05-21')])
# OrderedDict([('sessionId', '600651'), ('userId', 'NA'), ('itemId', '25816'), ('timeframe', '184664'), ('eventdate', '2016-05-21')])
# OrderedDict([('sessionId', '600653'), ('userId', 'NA'), ('itemId', '30623'), ('timeframe', '17443'), ('eventdate', '2016-04-10')])
# OrderedDict([('sessionId', '600661'), ('userId', 'NA'), ('itemId', '379345'), ('timeframe', '38430'), ('eventdate', '2016-05-15')])
# OrderedDict([('sessionId', '600661'), ('userId', 'NA'), ('itemId', '379345'), ('timeframe', '266322'), ('eventdate', '2016-05-15')])
# OrderedDict([('sessionId', '600661'), ('userId', 'NA'), ('itemId', '379345'), ('timeframe', '834638'), ('eventdate', '2016-05-15')])
# OrderedDict([('sessionId', '600661'), ('userId', 'NA'), ('itemId', '379345'), ('timeframe', '730845'), ('eventdate', '2016-05-15')])
# OrderedDict([('sessionId', '600663'), ('userId', 'NA'), ('itemId', '201958'), ('timeframe', '26346'), ('eventdate', '2016-05-02')])
# OrderedDict([('sessionId', '600669'), ('userId', 'NA'), ('itemId', '75148'), ('timeframe', '26705'), ('eventdate', '2016-04-18')])
# OrderedDict([('sessionId', '600672'), ('userId', 'NA'), ('itemId', '8141'), ('timeframe', '25615'), ('eventdate', '2016-05-13')])
# OrderedDict([('sessionId', '600672'), ('userId', 'NA'), ('itemId', '22587'), ('timeframe', '27568'), ('eventdate', '2016-05-13')])
# OrderedDict([('sessionId', '600674'), ('userId', 'NA'), ('itemId', '1152'), ('timeframe', '84848'), ('eventdate', '2016-05-27')])
# OrderedDict([('sessionId', '600674'), ('userId', 'NA'), ('itemId', '124642'), ('timeframe', '135066'), ('eventdate', '2016-05-27')])
# OrderedDict([('sessionId', '600674'), ('userId', 'NA'), ('itemId', '106930'), ('timeframe', '53456'), ('eventdate', '2016-05-27')])
# OrderedDict([('sessionId', '600680'), ('userId', '249344'), ('itemId', '31062'), ('timeframe', '142536'), ('eventdate', '2016-02-24')])
# OrderedDict([('sessionId', '600680'), ('userId', '249344'), ('itemId', '10274'), ('timeframe', '63474'), ('eventdate', '2016-02-24')])
# OrderedDict([('sessionId', '600680'), ('userId', '249344'), ('itemId', '36212'), ('timeframe', '27134'), ('eventdate', '2016-02-24')])
# OrderedDict([('sessionId', '600681'), ('userId', 'NA'), ('itemId', '8388'), ('timeframe', '483681'), ('eventdate', '2016-04-07')])
# OrderedDict([('sessionId', '600681'), ('userId', 'NA'), ('itemId', '9007'), ('timeframe', '127668'), ('eventdate', '2016-04-07')])
# OrderedDict([('sessionId', '600681'), ('userId', 'NA'), ('itemId', '33050'), ('timeframe', '377692'), ('eventdate', '2016-04-07')])
# OrderedDict([('sessionId', '600681'), ('userId', 'NA'), ('itemId', '33050'), ('timeframe', '412265'), ('eventdate', '2016-04-07')])
# OrderedDict([('sessionId', '600681'), ('userId', 'NA'), ('itemId', '33050'), ('timeframe', '448300'), ('eventdate', '2016-04-07')])
# OrderedDict([('sessionId', '600683'), ('userId', 'NA'), ('itemId', '9891'), ('timeframe', '29055'), ('eventdate', '2016-03-25')])
# OrderedDict([('sessionId', '600683'), ('userId', 'NA'), ('itemId', '3043'), ('timeframe', '273674'), ('eventdate', '2016-03-25')])
# OrderedDict([('sessionId', '600683'), ('userId', 'NA'), ('itemId', '101258'), ('timeframe', '143082'), ('eventdate', '2016-03-25')])
# OrderedDict([('sessionId', '600683'), ('userId', 'NA'), ('itemId', '163534'), ('timeframe', '117267'), ('eventdate', '2016-03-25')])
# OrderedDict([('sessionId', '600683'), ('userId', 'NA'), ('itemId', '101260'), ('timeframe', '213723'), ('eventdate', '2016-03-25')])
# OrderedDict([('sessionId', '600683'), ('userId', 'NA'), ('itemId', '243450'), ('timeframe', '185030'), ('eventdate', '2016-03-25')])
# OrderedDict([('sessionId', '600683'), ('userId', 'NA'), ('itemId', '10603'), ('timeframe', '86624'), ('eventdate', '2016-03-25')])
# OrderedDict([('sessionId', '600683'), ('userId', 'NA'), ('itemId', '10604'), ('timeframe', '13660'), ('eventdate', '2016-03-25')])
# OrderedDict([('sessionId', '600683'), ('userId', 'NA'), ('itemId', '120370'), ('timeframe', '248101'), ('eventdate', '2016-03-25')])
# OrderedDict([('sessionId', '600684'), ('userId', 'NA'), ('itemId', '42906'), ('timeframe', '632853'), ('eventdate', '2016-04-14')])
# OrderedDict([('sessionId', '600684'), ('userId', 'NA'), ('itemId', '33312'), ('timeframe', '643522'), ('eventdate', '2016-04-14')])
# OrderedDict([('sessionId', '600684'), ('userId', 'NA'), ('itemId', '33312'), ('timeframe', '52621'), ('eventdate', '2016-04-14')])
# OrderedDict([('sessionId', '600684'), ('userId', 'NA'), ('itemId', '5227'), ('timeframe', '575276'), ('eventdate', '2016-04-14')])
# OrderedDict([('sessionId', '600687'), ('userId', '249347'), ('itemId', '13296'), ('timeframe', '135288'), ('eventdate', '2016-02-16')])
# -- Reading data @ 2022-03-29 13:44:23.288096s
# Splitting date 1464134400.0
# 186670
# 15979
# [('4737', 1451606400.0), ('4741', 1451606400.0), ('4742', 1451606400.0)]
# [('289', 1464220800.0), ('290', 1464220800.0), ('302', 1464220800.0)]
# -- Splitting train set and test set @ 2022-03-29 13:44:30.036093s
# 43098
# 719470
# 60858
# [[1], [3, 4], [3]] [1451606400.0, 1451606400.0, 1451606400.0] [2, 5, 4]
# [[21553, 20071, 8762, 21566, 6381], [21553, 20071, 8762, 21566], [21553, 20071, 8762]] [1464220800.0, 1464220800.0, 1464220800.0] [21566, 6381, 21566]
# avg length:  4.850942344040704
# Done.
